# %% [markdown]
# # Извлечение данных из коллекции новостных текстов

# %%
from yargy import Parser, rule, or_, and_
from yargy.predicates import gram, dictionary, eq, is_capitalized, normalized, caseless
from yargy.interpretation import fact
from yargy.tokenizer import MorphTokenizer
from yargy.predicates import type as ytype
from yargy.predicates import gte, lte
from yargy.relations import gnc_relation
from yargy.pipelines import morph_pipeline
from dataclasses import dataclass
from typing import Optional

# %%
import os
current_directory = os.getcwd() 
file_path = os.path.join(current_directory, 'data', 'news.txt')

# %%
Entry = fact(
    'Entry',
    ['name', 'birth_date', 'birth_place']
)

# %%
NameFact = fact(
    'NameFact',
    ['name']
)

NAME = rule(
    gram('Name')
)

SURNAME = rule(
    gram('Surn')
)

PERSON_NAME = rule(
    NAME,
    SURNAME
).interpretation(NameFact.name)

# %%
parser_name = Parser(PERSON_NAME)

text_names_found = []
with open(file_path, 'r', encoding='utf-8') as file:
    for text in file:
        names_found = []
        for match in parser_name.findall(text):
            name_fact = match.fact
            names_found.append(name_fact)
        text_names_found.append(names_found)
text_names_found
# Out:
# [[],
#  ['Матс Сундин', 'Матс Сундин'],
#  ['Владимир Филиппов', 'Ильгизу Фахриеву', 'Михаилом Прохоровым'],
#  [],
#  [],
#  [],
#  ['Бена Николсона', 'Анри Матисса', 'Пабло Пикассо', 'Жоржа Брака'],
#  ['Владимиром Путиным'],
#  [],
#  ['Леонида Брежнева', 'Юрий Андропов'],
#  [],
#  ['Игоря Денисова', 'Игорь Денисов'],
#  [],
#  [],
#  [],
#  [],
#  ['Ларри Гагосян', 'Виктор Пинчук', 'Марину Абрамович'],
#  [],
#  [],
#  [],
#  ['Энди Коулсон', 'Руперта Мердока', 'Энди Коулсона'],
#  ['из еврокубковАрмейский', 'Леонида Слуцкого'],
#  [],
#  [],
#  ['Юлия Александрова',
#   'Елена Валюшкина',
#   'Валентина Мазулина',
#   'Андрея Першина'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Игорь Артемьев'],
#  ['Эльвира Набиуллина', 'Михаил Сухов'],
#  [],
#  [],
#  ['Владимиром Путиным'],
#  [],
#  [],
#  ['Владимир Долинский', 'Марина Могилевская', 'Анна Терехова'],
#  [],
#  ['Юрий Чайка',
#   'Александру Бастрыкину',
#   'Дениса Вороненкова',
#   'Отари Кобахидзе'],
#  ['Майкла Джексона', 'Ева Польна', 'Майкл Джексон'],
#  [],
#  ['Хайо Зеппельт',
#   'Ольга Скабеева',
#   'матчМария Шарапова',
#   'Григорий Родченков',
#   'Наталью Желанову'],
#  ['Вера Брежнева'],
#  [],
#  [],
#  ['Сергей Косырев', 'Дмитрия Циликина', 'марта Косырев', 'Дмитрий Циликин'],
#  ['Вагит Алекперов', 'Вагит Алекперов'],
#  ['Джастин Грэй'],
#  ['Сида Вишеса',
#   'Сидом Вишесом',
#   'Саймон Ричи',
#   'Алана Паркера',
#   'Сида Вишеса',
#   'Сид Вишес'],
#  [],
#  [],
#  [],
#  ['Александр Шпрыгин'],
#  ['Марку Цукербергу'],
#  [],
#  [],
#  ['Борис Гребенщиков', 'Борис Гребенщиков'],
#  [],
#  ['Джеки Смит', 'Джеки Смит', 'Джеки Смит'],
#  [],
#  [],
#  ['Галину Немову', 'Алексея Немова', 'Галина Немова', 'Дмитрий Чугунов'],
#  [],
#  [],
#  [],
#  ['Петер Вестербака'],
#  [],
#  [],
#  ['Дмитрий Песков', 'Виктора Кирьянова'],
#  [],
#  ['Дмитрий Комбаровы',
#   'Денис Глушаков',
#   'Евгений Макеев',
#   'Сергей Паршивлюк',
#   'Юра Мовсисян',
#   'Романом Широковым',
#   'Дмитрия Аленичева',
#   'Кирилла Комбарова'],
#  [],
#  [],
#  [],
#  ['Андрей Голубков'],
#  [],
#  ['Джозефа Киттингера'],
#  [],
#  ['Поля Сезанна',
#   'Поля Сезанна',
#   'Огюста Ренуара',
#   'Анри Матисса',
#   'Пабло Пикассо',
#   'Эдгара Дега',
#   'Клода Моне'],
#  ['Джанет Джексон',
#   'Джанет Джексон',
#   'Джанет Джексон',
#   'Джанет Джексон',
#   'Джанет Джексон',
#   'Майкл Джексон',
#   'Джанет Джексон'],
#  [],
#  ['Сара Полсон'],
#  [],
#  ['Владимир Путин',
#   'Дмитрий Песков',
#   'Дмитрий Рогозин',
#   'Сергей Шойгу',
#   'Валерий Герасимов',
#   'Юрий Борисов',
#   'Игорь Комаров'],
#  ['Андрея Мельниченко', 'Филипп Старк'],
#  [],
#  ['Владимир Путин'],
#  [],
#  ['Теунис Тенбрук', 'Теунис Тенбрук', 'Теуниса Тенбрука'],
#  [],
#  ['Алексей Кудрин', 'Алексей Кудрин'],
#  ['Льва Яшина',
#   'Льва Яшина',
#   'Карен Оганесян',
#   'Максим Матвеев',
#   'Валерии Харламове',
#   'Льву Яшину',
#   'Владимир Путин'],
#  ['Дени Мирзоева'],
#  [],
#  ['Авдотьи Смирновой',
#   'Алексея Сидорова',
#   'Олега Погодина',
#   'Карена Оганесяна',
#   'Алены Званцовой'],
#  ['Кевин Бейтс', 'Кевина Бейтса', 'Алексей Пажитнов'],
#  ['Дункана Брауна', 'Брюс Робертсон'],
#  [],
#  [],
#  ['Лидию Рыхлову', 'Дмитрию Рогозину', 'Владимира Липунова'],
#  ['Сергей Дарькин'],
#  ['Роджер Уотерс', 'Роджер Уотерс', 'Дэвид Гилмор', 'Ник Мейсон'],
#  ['Мария Захарова', 'Сергей Стрельбицкий'],
#  [],
#  ['Расселу Кроу', 'Расселу Кроу'],
#  ['Василий Быков', 'Василий Быков', 'Василий Быков'],
#  [],
#  [],
#  ['Леонарда Эйлера',
#   'Пафнутием Чебышевым',
#   'Георгом Риманом',
#   'Григорием Перельманом'],
#  [],
#  [],
#  [],
#  ['Джеймса Кэмерона'],
#  ['Марк Цукерберг'],
#  [],
#  [],
#  ['из титрова', 'Авдотья Смирнова'],
#  ['Гарри Поттер'],
#  ['Билл Мюррей', 'Джон Гудман'],
#  [],
#  [],
#  ['Джош Холлоуэй'],
#  ['Никиты Хрущева', 'Сергея Королева'],
#  [],
#  [],
#  [],
#  [],
#  ['Джон Ангер', 'Джон Ангер', 'Джон Ангер'],
#  [],
#  [],
#  [],
#  ['Дмитрий Муратов'],
#  ['Мэтт Смит'],
#  [],
#  ['Брент Сибрук', 'Джеффа Картера', 'Вячеслав Войнов'],
#  ['Лиама Галлахера', 'Лиам Галлахер', 'Руперта Мердока'],
#  [],
#  ['Крэйг Райт'],
#  ['Василий Баранов', 'Владимира Путина'],
#  ['Ивана Таврина', 'Алишера Усманова'],
#  ['Александр Невзоров',
#   'Валентины Матвиенко',
#   'Александра Невзорова',
#   'Александра Невзорова',
#   'Александр Невзоров'],
#  [],
#  ['Оливер Экман',
#   'Антон Худобин',
#   'Сергей Плотников',
#   'Сергей Мозякин',
#   'Александр Попов',
#   'Олега Знарка'],
#  ['Владимир Путин', 'Игорь Шувалов', 'Андрей Белоусов'],
#  [],
#  [],
#  [],
#  ['Джульетта Старлинг'],
#  ['Кристиан Шмидт', 'Николаем Федоровым'],
#  [],
#  ['Дмитрий Медведев'],
#  [],
#  [],
#  ['Владимир Путин',
#   'Владимира Нестерова',
#   'Дмитрий Медведев',
#   'Владимира Поповкина'],
#  [],
#  [],
#  [],
#  [],
#  ['Владимиром Путиным', 'Дмитрием Медведевым', 'Яков Силин'],
#  ['Дмитрий Медведев'],
#  ['Арсений Яценюк', 'Дмитрий Песков', 'Наталья Яресько'],
#  ['Николая Жердева'],
#  [],
#  ['Томми Ли', 'Томми Ли', 'Крис Купер'],
#  ['Владимир Путин'],
#  [],
#  [],
#  [],
#  ['Кристин Райт'],
#  [],
#  ['Муаммаром Каддафи', 'Муаммара Каддафи'],
#  ['Александр Грушко', 'Федор Лукьянов', 'Владимир Путин'],
#  [],
#  [],
#  [],
#  ['Анджея Сапковского'],
#  ['Романа Терюшкова'],
#  [],
#  [],
#  ['Стивен Уилсон'],
#  [],
#  [],
#  [],
#  [],
#  ['Аркадий Ткачук', 'Георгий Перский', 'Аркадий Ткачук'],
#  [],
#  ['Ксении Собчак',
#   'Ксенией Собчак',
#   'Борис Немцов',
#   'Алексей Навальный',
#   'Ксения Собчак',
#   'Ксения Собчак',
#   'Ксения Собчак'],
#  ['Барак Обама', 'Мишель Обама', 'Барак Обама'],
#  ['Джош Сингер'],
#  ['Адольфа Гитлера'],
#  [],
#  [],
#  [],
#  ['Нил Мориц'],
#  ['Валерий Ничушкин',
#   'Александр Хохлачев',
#   'Кирилл Дьяков',
#   'Михаил Григоренко'],
#  [],
#  ['Олега Пешкова',
#   'Олега Пешкова',
#   'Виктор Бондарев',
#   'Олег Королев',
#   'Олег Пешков',
#   'Константин Мурахтин'],
#  ['Вагит Алекперов'],
#  ['Арнольдом Шварценеггером'],
#  [],
#  ['Валон Бериша'],
#  ['Сергей Ковалев'],
#  ['Петр Лукьянов',
#   'Юрием Добровольским',
#   'Сергеем Нефедкиным',
#   'Данилой Шапошниковым',
#   'Петром Лукьяновым',
#   'Ольгой Маслиховой'],
#  [],
#  ['Алексея Навального', 'Никиты Белых'],
#  [],
#  [],
#  ['Дмитрий Медведев'],
#  [],
#  ['Альбрехта Дюрера'],
#  ['В Истборне'],
#  [],
#  ['Даниэль Баренбойм', 'Анна Нетребко', 'Амадеем Моцартом', 'Луиджи Манцотти'],
#  ['Майкла Джексона', 'Майкла Джексона', 'Майкл Джексон'],
#  ['Марка Цукерберга', 'Николя Саркози'],
#  ['Руперта Мердока', 'Руперт Мердок'],
#  [],
#  [],
#  ['Джеймса Бонда', 'Джеймса Бонда', 'Джеймсе Бонде'],
#  ['Олег Груненков'],
#  [],
#  ['Наполеоном Бонапартом'],
#  ['Николая Азарова'],
#  [],
#  [],
#  ['Элвиса Пресли', 'Элвиса Пресли', 'Ричардом Никсоном'],
#  ['Вячеслав Першуков', 'Андрей Говердовский'],
#  ['из городов'],
#  ['Михаила Глущенко',
#   'Галины Старовойтовой',
#   'Владимира Барсукова',
#   'Галина Старовойтова'],
#  ['Андрей Белоусов'],
#  ['Михаила Ходорковского'],
#  ['Юрий Бойко'],
#  [],
#  [],
#  [],
#  [],
#  ['Илью Ковальчука',
#   'Станислав Галимов',
#   'Эмиль Гарипов',
#   'Александр Еременко',
#   'Михаил Григорьев',
#   'Денис Денисов',
#   'Никита Зайцев',
#   'Дмитрий Калинин',
#   'Евгений Рясенский',
#   'Глеб Корягин',
#   'Андрей Миронов',
#   'Александр Кутузов',
#   'Евгений Медведев',
#   'Илья Никулин',
#   'Александр Бурмистров',
#   'Михаил Варнаков',
#   'Кирилл Петров',
#   'Владимир Глазулин',
#   'Антон Глинкин',
#   'Евгений Дадонов',
#   'Илья Зубов',
#   'Сергей Калинин',
#   'Сергей Широков',
#   'Максим Карпов',
#   'Максим Пестушко',
#   'Илья Ковальчук',
#   'Артемий Панарин',
#   'Виктор Тихонов',
#   'Евгений Шипачев',
#   'Дмитрий Кугрышев',
#   'Николай Прохоркин',
#   'Федор Малыхин'],
#  ['Виктора Януковича'],
#  [],
#  [],
#  ['Юрий Чайка', 'Алексей Ведев'],
#  [],
#  [],
#  [],
#  ['Константином Мурахтиным', 'Игорь Конашенков', 'Олег Пешков'],
#  ['Дмитрий Медведев',
#   'Алексея Улюкаева',
#   'Алексей Улюкаев',
#   'Владимиру Путину'],
#  [],
#  [],
#  ['Джона Леннона'],
#  [],
#  [],
#  ['Виктор Лысенко'],
#  [],
#  [],
#  ['Дмитрий Панкин'],
#  [],
#  ['Сергей Лазарев', 'Филипп Киркоров'],
#  [],
#  ['В Московском', 'Ольгу Гореловскую'],
#  ['Баннинга Кока'],
#  [],
#  ['Джанни Инфантино'],
#  ['Владислав Масалов', 'Владислав Масалов'],
#  [],
#  ['Айдан Салаховой',
#   'Ильхам Алиев',
#   'Айдан Салаховой',
#   'Юрий Аввакумов',
#   'Айдан Салаховой',
#   'Айдан Салахова'],
#  ['Елена Исинбаева',
#   'Анна Чичерова',
#   'Елена Слесаренко',
#   'Татьяна Лысенко',
#   'Юлия Зарипова',
#   'Мария Савинова',
#   'Юлия Гущина',
#   'Елена Лашманова',
#   'Ольга Каниськина',
#   'Иван Ухов',
#   'Юрий Борзаковский',
#   'Сергей Кирдяпкин',
#   'Татьяна Лебедева'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Максима Кашулинского', 'Александр Винокуров'],
#  [],
#  [],
#  ['Николя Саркози'],
#  [],
#  [],
#  [],
#  ['Владимир Якунин', 'Максим Соколов', 'Владимир Якунин'],
#  ['Сильвио Берлускони', 'Сильвио Берлускони', 'Дженна Джеймсон', 'Саша Грей'],
#  ['Евгений Савченко',
#   'Владимир Путин',
#   'Дмитрий Медведев',
#   'Владимир Жириновский'],
#  [],
#  [],
#  ['Александра Зубкова', 'Дмитрий Труненков'],
#  ['Дмитрий Гуджоян', 'Олег Бударгин', 'Владимир Путин', 'Владимир Путин'],
#  ['Джессика Симпсон', 'Джессика Симпсон'],
#  ['Лизанн Фальк'],
#  ['Владимира Кличко', 'Владимира КличкоФьюри', 'Владимир Кличко'],
#  ['Фредди Крюгера',
#   'Юэль Киннаман',
#   'Гэри Олдман',
#   'Хью Лори',
#   'Фредди Крюгера'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Михаила Гуцериева',
#   'Алихан Гуцериев',
#   'Алихан Гуцериев',
#   'Михаила Гуцериева',
#   'Алихан Гуцериев',
#   'Михаил Гуцериев'],
#  ['Бенедикт Хэнкок'],
#  ['Александр Петров', 'Евгением Плющенко'],
#  [],
#  ['ли Ромни', 'Барак Обама'],
#  [],
#  [],
#  ['Брюс Дикинсон', 'Майкла Дугласа', 'Майкл Дуглас', 'Стив Харрис'],
#  ['Пола Верховена'],
#  ['Сергей Шубенков', 'Дарья Клишина'],
#  [],
#  [],
#  ['Кубрат Пулев', 'Владимиром Кличко'],
#  [],
#  ['Андрея Зализняка'],
#  ['Рэнди Гербера'],
#  [],
#  [],
#  [],
#  ['Александра Овечкина', 'Евгением Малкиным'],
#  [],
#  [],
#  [],
#  ['Джейсон Рубин', 'Джейсон Рубин'],
#  ['цвет по'],
#  ['Джанни Инфантино', 'Джанни Инфантино'],
#  ['Павел Хамидулин'],
#  ['из Тюбингенского'],
#  ['Илья Ткаченко',
#   'Екатериной Рязановой',
#   'Алексей Горшков',
#   'Мерил Дэвис',
#   'Чарли Уайт',
#   'Елена Ильиных',
#   'Екатерина Боброва',
#   'Дмитрий Соловьев'],
#  ['Джоэл Коэны', 'Джоэл Коэны', 'Тони Блэр'],
#  [],
#  ['Бориса Грызлова', 'Дмитрий Грызлов', 'Дмитрий Грызлов', 'Дмитрия Грызлова'],
#  ['Джеймс Уильямсон'],
#  ['Ирина Тюрина'],
#  ['Сергея Швецова'],
#  ['ли Каплан'],
#  ['Ричарда Макларена'],
#  ['Дмитрий Козак', 'Искандара Махмудова', 'Владимира Потанина'],
#  [],
#  [],
#  [],
#  ['Владимир Поповкин', 'Владимир Поповкин'],
#  ['Захар Прилепин',
#   'Захар Прилепин',
#   'Михаила Тарковского',
#   'Евгения Водолазкина',
#   'Владимира Маяковского',
#   'Лилии Брик'],
#  [],
#  ['Алексея Навального',
#   'Константина Янкаускаса',
#   'Ольга Горелик',
#   'Константин Янкаускас',
#   'Алексея Навального',
#   'Владимир Ашурков',
#   'Николай Ляскин',
#   'Константин Янкаускас',
#   'Владимир Ашурков',
#   'Николай Ляскин'],
#  [],
#  [],
#  ['Юрия Лужкова', 'Владимиру Путину', 'Леонида Гозмана', 'Бориса Немцова'],
#  [],
#  [],
#  ['из Эксетерского'],
#  ['Сергея Румянцева'],
#  ['Артур Анишин', 'Юрия Валуева'],
#  ['Салаватом Юлаевым'],
#  [],
#  [],
#  ['Сергея Полонского', 'Дмитрию Луценко'],
#  ['Тима Бертона', 'Джейсон Шварцман'],
#  ['Джин Сперлинг', 'Барака Обамы'],
#  ['В киберпанковой', 'Майка Пондсмита'],
#  [],
#  ['Евгений Гинер', 'Николай Толстых'],
#  ['Александр Маркин',
#   'Мария Шарапова',
#   'Мария Шарапова',
#   'Семен Елистратов',
#   'Екатерина Боброва',
#   'Александр Маркин'],
#  [],
#  [],
#  [],
#  ['Юрий Иванов', 'Юрий Иванов', 'Юрий Иванов'],
#  ['Александр Зубков', 'Александр Зубков'],
#  [],
#  [],
#  [],
#  ['Никита Крылов', 'Юрий Бирюков'],
#  ['Денис Лебедев', 'Денис Лебедев', 'Владимир Хрюнов'],
#  [],
#  [],
#  ['Игорь Бутман', 'Юрий Башмет', 'Мария Александрова', 'Юрий Башмет'],
#  [],
#  ['Джон Ранкин', 'Мария Криттель'],
#  [],
#  [],
#  [],
#  ['Брайан Уилсон',
#   'Майк Лав',
#   'Алан Джардин',
#   'Дэвид Маркс',
#   'Крис Браун',
#   'Тони Беннетт'],
#  [],
#  ['из худшихЧерноморский'],
#  [],
#  [],
#  ['Майкл Блумберг'],
#  ['Эльвира Набиуллина', 'Ярослава Кузьминова', 'Эльвира Набиуллина'],
#  [],
#  ['Арама Габрелянова'],
#  ['Владимира Путина'],
#  ['Михаила Саакашвили', 'Кирилла Миронова'],
#  ['Вагит Алекперов', 'Игорь Шувалов', 'Дмитрий Медведев'],
#  ['Ларри Клейман', 'Марка Цукерберга'],
#  ['Дмитрий Медведев'],
#  ['Андрей Рябинский', 'Ричарда Макларена'],
#  ['Николай Грачев'],
#  ['Вагит Алекперов'],
#  ['Дмитрию Медведеву', 'Владимиру Путину'],
#  ['Андрея Костина'],
#  [],
#  ['Сергей Прядкин', 'Дмитрий Медведев'],
#  ['Филипп Шмитт'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Сандра Буллок'],
#  [],
#  ['Олег Жолобов', 'Владимир Максимов'],
#  ['Андрея Колесникова'],
#  ['Никита Одинцов',
#   'Павла Астахова',
#   'Антон Астахов',
#   'Павла Астахова',
#   'Анна Левченко',
#   'Николай Никифоров'],
#  [],
#  [],
#  [],
#  ['Ридли Скоттов', 'августа по', 'Кирилла Серебренникова'],
#  [],
#  [],
#  ['Александр Круглов'],
#  [],
#  [],
#  ['из баров', 'Стива Джобса'],
#  [],
#  [],
#  ['Станислав Воскресенский', 'Барак Обама'],
#  [],
#  [],
#  [],
#  ['Дэвид Гибсон', 'Джейк Дэвис'],
#  ['Екатерина Михайлова'],
#  ['Константина Коровина',
#   'Петра Кончаловского',
#   'Александра Яковлева',
#   'Святослава Рериха',
#   'Ивана Айвазовского',
#   'Ильи Репина',
#   'Ивана Шишкина'],
#  [],
#  [],
#  ['Владимир Путин',
#   'Андрея Курносенко',
#   'Андрей Курносенко',
#   'Дениса Сугробова'],
#  [],
#  [],
#  ['Мэрилин Монро', 'Мэрилин Монро', 'Ральфа Гринсона'],
#  ['Илья Сорокин',
#   'Игорь Шестеркин',
#   'Василий Демченко',
#   'Виктор Антипин',
#   'Алексей Береглазов',
#   'Илья Любушкин',
#   'Игорь Ожиганов',
#   'Андрей Миронов',
#   'Никита Гусев',
#   'Николай Прохоркин',
#   'Александр Барабанов',
#   'Анатолий Голышев',
#   'Валерий Ничушкин',
#   'Степан Санников',
#   'Сергей Шумаков',
#   'Константин Окулов',
#   'Владимир Ткачев',
#   'Вячеслав Лещенко',
#   'Павел Красковский'],
#  ['Леонид Левин'],
#  [],
#  ['Наталья Пучкова'],
#  [],
#  [],
#  ['Владимира Чистюхина'],
#  ['Кристиной Киршнер'],
#  [],
#  ['Владимир Пепеляев'],
#  ['Федором Бондарчуком',
#   'Александр Войтинский',
#   'Алексей Кравченко',
#   'Никита Волков',
#   'Ксения Алферова'],
#  [],
#  [],
#  ['Рамзан Кадыров',
#   'Федора Емельяненко',
#   'Федора Емельяненко',
#   'Рамзана Кадырова',
#   'Рамзана Кадырова'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Владимира Путина'],
#  [],
#  ['Станислава Черчесова', 'Леонид Слуцкий'],
#  ['Давид Лагеркранц'],
#  ['Сергей Шойгу'],
#  [],
#  ['Дженис Джонсен', 'Майк Джонсен', 'Дженис Джонсен'],
#  [],
#  [],
#  ['Джеймс Кэмерон',
#   'Джеймс Кэмерон',
#   'Джоша Фридмана',
#   'Стивена Спилберга',
#   'ли Фридман',
#   'Джеймса Кэмерона'],
#  [],
#  [],
#  ['Сандра Буллок', 'Сандра Буллок', 'Джим Парсонс', 'Шелдона Купера'],
#  [],
#  [],
#  [],
#  [],
#  ['Алла Забровская'],
#  [],
#  [],
#  ['Дмитрия Медведева'],
#  [],
#  ['Александр Кокорин', 'Александер Бюттнер'],
#  [],
#  [],
#  ['Вагнер Лав', 'Вагнер Лав'],
#  ['Майкл Уилсон'],
#  ['Виктор Зюкин', 'Олега Сафонова', 'августа по'],
#  [],
#  [],
#  [],
#  ['Стивен Лоуитс'],
#  ['Франческо Тотти'],
#  ['Дмитрием Медведевым', 'Сергей Когогин'],
#  [],
#  ['Борис Гребенщиков',
#   'Геннадий Авраменко',
#   'Анатолием Гуницким',
#   'Михаилом Саакашвили',
#   'Вячеславом Бутусовым',
#   'Юрием Шевчуком',
#   'Максимом Леонидовым'],
#  [],
#  ['Башевиса Зингера', 'Андре Янг', 'Гарри Бендинере'],
#  ['Андрей Костин', 'Игорю Шувалову'],
#  [],
#  ['Йосипа Шимунича'],
#  [],
#  ['Бонэм Картер', 'Алана Рикмана'],
#  [],
#  [],
#  [],
#  [],
#  ['Ислам Каримов'],
#  ['Стивена Кинга'],
#  [],
#  [],
#  [],
#  ['Владимир Мединский'],
#  [],
#  [],
#  [],
#  ['Алин Смит', 'Джастина Бибера', 'Дион Смита', 'Алин Смит'],
#  [],
#  ['Сесара Родригеса'],
#  [],
#  [],
#  ['Дэвида Эберсмана'],
#  [],
#  [],
#  [],
#  ['Джиму Керри', 'Джиму Керри', 'Джим Керри', 'Джима Керри'],
#  ['Арнольд Шварценеггер'],
#  ['Роман Широков'],
#  ['сами по'],
#  ['Грег Гекнер', 'Дэна Гликмана'],
#  [],
#  ['Виктора Бондарева'],
#  [],
#  ['оглы Махмудов', 'Евгений Кириллюк'],
#  ['Кузьме Минину', 'Дмитрию Пожарскому'],
#  ['Александра Фомина'],
#  ['арена московского',
#   'Сергея Шойгу',
#   'Владимира Путина',
#   'Всеволода Боброва',
#   'аренами московского',
#   'Александра Радулова',
#   'Вячеслав Фетисов'],
#  ['Томаса Андерсона', 'Филип Сеймур', 'Шон Комбс'],
#  ['Кристал Ли'],
#  [],
#  ['Михаил Погосян'],
#  [],
#  ['сами по'],
#  [],
#  ['Дарья Гаврилова', 'Светлана Кузнецова', 'Элины Свитолиной'],
#  [],
#  ['Валентин Распутин', 'Валерий Ганичев'],
#  ['Дмитрий Тулин', 'Алексей Моисеев'],
#  ['Иосиф Кобзон', 'Иосиф Кобзон'],
#  [],
#  ['Виктора Цоя',
#   'Лев Шлосберг',
#   'Сергею Собянину',
#   'Александр Агеев',
#   'Виктора Цоя',
#   'Ирина Жирнова'],
#  [],
#  ['Вадим Ампелонский', 'Станислава Казакова', 'Дмитрий Зяблицев'],
#  ['Барак Обама'],
#  ['Андре Янг'],
#  [],
#  ['Константином Новоселовым'],
#  [],
#  ['Джейкоб Хансен'],
#  ['Александр Кокорин', 'Леонид Слуцкий'],
#  ['Сиенне Миллер', 'Роберту Паттинсону', 'Джеймс Грэй'],
#  [],
#  [],
#  ['Дмитрий Горин'],
#  ['Александр Овечкин', 'Александр Овечкин', 'Александр Овечкин'],
#  [],
#  [],
#  [],
#  ['Алан Дзагоев', 'Вагнер Лав'],
#  ['Джона Леннона',
#   'Элвиса Пресли',
#   'Джону Леннону',
#   'Курту Кобейну',
#   'Майклу Джексону'],
#  ['Анатолий Калмыков'],
#  ['Барак Обама', 'Роберт Гиббс', 'Барак Обама'],
#  ['Дениса Глушакова', 'Дениса Глушакова'],
#  ['Сергей Лавров', 'Софико Шеварнадзе', 'Сергей Лавров'],
#  ['Сантьяго Бернабеу'],
#  ['из охотников', 'Джордж Буш'],
#  [],
#  ['Сергей Шойгу', 'Виталий Чуркин'],
#  ['Владимир Фортов'],
#  [],
#  [],
#  ['Евгению Онегину',
#   'Евгений Онегин',
#   'Александра Пушкина',
#   'Евгения Онегина',
#   'Гарри Поттере'],
#  ['Кристиана Лакруа'],
#  [],
#  ['Шалва Озманов'],
#  ['Игоря Рябинникова'],
#  ['Валерия Герасимова'],
#  ['Андрей Назаров',
#   'Анастасию Лебедеву',
#   'Максима Семенова',
#   'Александра Свитова'],
#  ['Владимир Константинов', 'Сергей Миронов', 'Сергей Аксенов'],
#  ['Игорь Баринов'],
#  [],
#  [],
#  [],
#  ['Уэйн Трансо'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Игорь Насенков', 'Юрий Маевский'],
#  [],
#  [],
#  ['Джона Толкиена',
#   'романы Толкиена',
#   'Питера Джексона',
#   'Джона Грина',
#   'Том Гейтс',
#   'Гарри Поттер',
#   'Джон Толкиен',
#   'Питер Джексон'],
#  ['Виктора Калинушкина'],
#  ['Тайо Круз'],
#  ['Сергей Галахов', 'Владимира Высоцкого'],
#  [],
#  ['Владимиром Путиным'],
#  [],
#  ['Геннадий Тимченко',
#   'Геннадий Тимченко',
#   'Геннадия Тимченко',
#   'Владимира Якунина',
#   'Юрия Ковальчука',
#   'Бориса Ротенбергов',
#   'Барак Обама',
#   'Владимира Путина'],
#  ['Валентин Дьяконов', 'Надежда Беляева', 'Юлия Тавризян'],
#  ['Дональда Трампа', 'Дональда Трампа', 'Дональд Трамп'],
#  ['Феликсу Дзержинскому',
#   'Сергея Сперанского',
#   'Евгения Вучетича',
#   'Михаила Шмакова',
#   'Михаила Лермонтова',
#   'Исаака Бродского',
#   'Сергея Чаплыгина',
#   'Юрия Гольского',
#   'Зиновия Виленского',
#   'Алексея Щусева',
#   'Иулиана Рукавишникова',
#   'Феликсу Дзержинскому',
#   'Владимир Колесников'],
#  [],
#  ['Татьяна Белова', 'Елены Гороховой'],
#  [],
#  [],
#  [],
#  ['Хью Джекмана',
#   'Хью Джекмана',
#   'Томаса Хупера',
#   'Виктора Гюго',
#   'Мишеля Шонберга',
#   'Уильям Николсон',
#   'Хью Джекман'],
#  [],
#  ['Стивен Кинг', 'Стивен Кинг', 'Эльвиры Набиуллиной'],
#  [],
#  ['Юрий Соловьев', 'Михаила Фридмана', 'Матс Гранрид'],
#  [],
#  [],
#  ['Алексей Митрофанов'],
#  ['Илья Островский'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Владимира Путина'],
#  ['Бетт Мидлер'],
#  ['Михаил Горбачев', 'Михаилу Горбачеву'],
#  [],
#  ['Шерлок Холмс', 'Стивена Спилберга'],
#  [],
#  ['Вадим Пищейко', 'Николай Азаров'],
#  [],
#  ['Пабло Пикассо'],
#  ['Джон Коутс'],
#  ['Сергея Плуготаренко',
#   'Кирилла Варламова',
#   'Сергея Петрова',
#   'Германа Клименко',
#   'Леонид Левин',
#   'Леонид Левин',
#   'Вячеслав Володин'],
#  [],
#  ['Аркадий Злочевский', 'Владимира Путина'],
#  ['Вадим Александрович',
#   'Максим Александрович',
#   'Иван Александрович',
#   'Дмитрий Александрович'],
#  ['Билл Гейтс'],
#  ['Жан Семенов'],
#  [],
#  [],
#  ['Карл Икан'],
#  ['Олег Белозеров', 'Владимир Якунин', 'Михаил Акулов'],
#  [],
#  ['Михаила Орленко'],
#  ['Сергей Шаргунов',
#   'Владимир Сорокин',
#   'Владимир Шаров',
#   'Павел Крусанов',
#   'Марат Басыров',
#   'Михаил Елизаров',
#   'Вероника Емелина',
#   'Аглая Топорова',
#   'Дмитрий Ольшанский',
#   'Лиля Ким',
#   'Ксения Рождественская',
#   'Татьяна Геворкян',
#   'Борис Куприянов',
#   'Алексей Лебедев',
#   'Екатерина Чеботарева',
#   'Константином Тублиным'],
#  [],
#  [],
#  [],
#  ['Киану Ривз'],
#  ['Паскаль Герлен'],
#  ['Александра Бастрыкина',
#   'Анатолия Сердюкова',
#   'Юрия Лужкова',
#   'Иван Шубин',
#   'Владимир Сунгоркин'],
#  [],
#  [],
#  ['Дэн Ауэрбах', 'Джефф Бек'],
#  ['Кирилла Банецкого'],
#  ['Бориса Кочиева',
#   'Ренат Кочиев',
#   'Борис Кочиев',
#   'Бориса Кочиева',
#   'Джона Рида',
#   'Борис Кочиев'],
#  [],
#  [],
#  ['Валентина Серова', 'Зельфирой Трегуловой', 'Валентин Серов'],
#  [],
#  ['Сергея Васильева',
#   'Эдуард Райкин',
#   'Сергей Васильев',
#   'Алексея Мордашова',
#   'Эдуард Райкин'],
#  ['Сергеем Разиным', 'Сергея Разина'],
#  ['Олегом Кононенко'],
#  ['Мила Селямиева'],
#  [],
#  [],
#  [],
#  ['Юсуф Хаджисулейман', 'Владимир Путин'],
#  [],
#  ['Джесси Пинкмана'],
#  [],
#  ['Тимура Бекмамбетова'],
#  [],
#  ['Ричард Макларен'],
#  [],
#  [],
#  ['Дмитрий Калинин',
#   'Юрий Александров',
#   'Александр Кучерявенко',
#   'Евгений Артюхин',
#   'Денис Казионов',
#   'Михаил Анисин'],
#  ['Дэвид Бениофф', 'Софи Тернер'],
#  [],
#  [],
#  [],
#  ['Николай Королев', 'Олег Сафонов'],
#  ['Сергей Дубинин'],
#  ['Аугусто Пиночета', 'Сальвадора Альенде'],
#  ['Виктору Шкулеву', 'Андрея Цыганова'],
#  [],
#  ['из городов'],
#  ['Барака Обаму', 'Ангелы Меркель'],
#  ['Владимира Фролова',
#   'Марат Гельман',
#   'Айдан Салахова',
#   'Сергей Фролов',
#   'Сергей Фролов',
#   'Владимир Фролова'],
#  ['Стэнли Коэном'],
#  ['Роналду по'],
#  ['Франсуа Олландом', 'Бернар Арно', 'Жерар Депардье'],
#  ['Виталий Савельев'],
#  [],
#  [],
#  ['Леонида Слуцкого'],
#  [],
#  [],
#  ['Александру Хрусталеву'],
#  [],
#  ['Эдики Лялиной',
#   'Эдика Лялина',
#   'Артему Хотееву',
#   'Эдика Лялина',
#   'Артема Хотеева'],
#  [],
#  ['Диана Арбенина',
#   'Дианы Арбениной',
#   'Диана Арбенина',
#   'Диана Арбенина',
#   'Александр Иванов',
#   'Алекс Хепберн'],
#  ['Камиль Магомедов'],
#  ['Александр Овечкин', 'Тайлера Сегина', 'Сергея Федорова'],
#  [],
#  [],
#  ['Германа Лопаткина', 'Алексея Навального', 'Герман Лопаткин'],
#  [],
#  [],
#  ['Александра Ткачева', 'Андрей Даниленко'],
#  ['Константин Клещев'],
#  [],
#  ['Фаддея Беллинсгаузена'],
#  ['Александр Дюков'],
#  [],
#  ['Вадим Горюнов'],
#  [],
#  [],
#  [],
#  [],
#  ['Всеволод Вуколов'],
#  ['Виктора Евтухова'],
#  ['Сиенне Миллер', 'Гордону Тейлору', 'Руперт Мердок'],
#  ['Василий Уткин', 'Сергей Федоров', 'Алексей Кортнев'],
#  [],
#  ['Владимир Сафронов', 'Михаил Сухов'],
#  ['Владимир Путин', 'Дмитрием Медведевым', 'сами по'],
#  ['из Вюрцбургского'],
#  [],
#  ['Рэйчел Грин'],
#  ['Роджером Уотерсом', 'Ником Мейсоном', 'Роджер Уотерс', 'Алан Паркер'],
#  [],
#  ['Максима Дегтярева', 'Герман Греф'],
#  ['Александр Нерадько', 'Сергей Петухов'],
#  [],
#  [],
#  ['Анны Седоковой',
#   'Матвей Мельников',
#   'Артема Пивоварова',
#   'Никиты Алексеева',
#   'Артем Пивоваров',
#   'Елена Темникова',
#   'Анна Седокова'],
#  [],
#  ['Роджеру Федереру'],
#  [],
#  ['Луи Брандтом', 'Базза Олдрина', 'Алексей Леонов'],
#  [],
#  ['Евгений Алдонин',
#   'Игорь Семшов',
#   'Александр Ширко',
#   'Руслан Пименов',
#   'Александром Елагиным',
#   'Владимиром Стогниенко',
#   'Руслан Нигматуллин'],
#  ['Луиза Уайт', 'Луизы Уайт', 'Луиза Уайт'],
#  [],
#  ['Дмитрий Горин'],
#  [],
#  [],
#  ['Майклом Джексоном'],
#  ['Игорь Шувалов', 'Зиявудина Магомедова'],
#  [],
#  [],
#  ['Ангелы Меркель', 'Франсуа Олланда', 'Ангелы Меркель'],
#  ['Александр Лебедев'],
#  [],
#  [],
#  ['Руперта Мердока', 'Дэвид Кэмерон', 'Энди Коулсон'],
#  [],
#  [],
#  [],
#  ['Дмитрий Медведев', 'Владимир Путин'],
#  [],
#  [],
#  [],
#  [],
#  ['Нэнси Гиббс', 'Нэнси Гиббс', 'Нэнси Гиббс'],
#  [],
#  [],
#  ['Деонтей Уайлдер', 'Александра Поветкина', 'Андрей Рябинский'],
#  [],
#  ['Владимир Гутенев'],
#  [],
#  [],
#  [],
#  ['Дмитрий Рогозин', 'Владислав Масалов'],
#  ['Ник Байдин'],
#  [],
#  ['Александр Сухоруков', 'Анатолий Сердюков'],
#  [],
#  ['Зоры Сежнковой'],
#  ['Льва Толстого',
#   'Никола Баркер',
#   'Владимир Толстой',
#   'Льва Толстого',
#   'Нил Гейман'],
#  ['Федор Емельяненко', 'Федор Емельяненко', 'Федор Емельяненко'],
#  ['Александр Базаров'],
#  ['Игорь Елкин', 'Гюнтера Эттингера', 'Сабина Бергер'],
#  ['Арина Матвеева', 'Михаил Саакашвили'],
#  [],
#  [],
#  ['Яна Чурикова',
#   'Саша Фролова',
#   'Антон Лаврентьев',
#   'Дмитрий Исхаков',
#   'Лиза Кудроу'],
#  ['Филип Сеймур', 'Кэтрин Кинер', 'Ярон Зилберман'],
#  ['Кортни Лав', 'Кортни Лав', 'Кортни Лав', 'Келли Осборн', 'Том Круз'],
#  ['Елена Мясникова',
#   'Михаила Прохорова',
#   'Сергей Лаврухин',
#   'Елена Мясникова'],
#  [],
#  ['Коринна Гарднер'],
#  ['Соня Картер'],
#  [],
#  [],
#  ['Андрей Новиков', 'Андрей Вдовин'],
#  ['Александр Ткачев'],
#  ['Аллен Кейн',
#   'Балтиморе Эрин',
#   'Аллен Кейн',
#   'Фредди Грея',
#   'Фредди Грея',
#   'Аллен Кейн'],
#  ['Евгений Гараничев', 'Алексей Волков', 'Максим Цветков'],
#  [],
#  ['Виктор Янукович',
#   'Богдан Хмельницкий',
#   'Николая Костомарова',
#   'Ивана Франко',
#   'Петра Кононенко',
#   'Владимира Ельченко'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Макса Планка'],
#  [],
#  ['романа Орсона', 'герой романа', 'Петру Акарнян'],
#  ['Сати Казановой', 'Сати Казанова'],
#  ['Мариса Миллер'],
#  [],
#  [],
#  [],
#  ['Алексей Мордашов', 'Алексей Мордашов'],
#  [],
#  [],
#  ['Элвиса Пресли',
#   'Элвис Пресли',
#   'Тони Беннетт',
#   'Рой Орбисон',
#   'Элвис Пресли',
#   'Бобби Винтон'],
#  [],
#  ['Александр Горшков'],
#  [],
#  [],
#  ['Ноэль Галлахер', 'Рик Симпсон'],
#  ['Джорджа Харрисона'],
#  ['Клаудио Раньери'],
#  ['Дональд Трамп', 'Тед Круз', 'Мелании Трамп', 'Мелании Трамп'],
#  ['Юрий Шевчук',
#   'Артемия Троицкого',
#   'Юрий Шевчук',
#   'Николая Хованского',
#   'Николай Хованский',
#   'Анатолия Баркова',
#   'Вера Сидельникова',
#   'Николай Хованский',
#   'Артемия Троицкого',
#   'Артемий Троицкий',
#   'Агата Кристи',
#   'Вадим Самойлов',
#   'Артемия Троицкого',
#   'Юрий Шевчук',
#   'Вася Обломов'],
#  ['Иван Виноградов', 'Константином Бороздиным'],
#  [],
#  [],
#  [],
#  [],
#  ['Денис Черышев'],
#  [],
#  [],
#  [],
#  [],
#  ['Сильвио Берлускони'],
#  ['Сергея Образцова', 'Сергей Образцов'],
#  [],
#  ['Стивен Спилберг'],
#  [],
#  ['Владимир Путин', 'Эльвирой Набиуллиной'],
#  ['Карло Анчелотти'],
#  [],
#  ['Германа Грефа', 'Дмитрий Медведев', 'Алексей Моисеев'],
#  [],
#  ['Тони Стюарт'],
#  [],
#  ['Наталью Желанову'],
#  [],
#  [],
#  ['Рустем Адагамов'],
#  ['О Гагарине', 'Юрием Гагариным'],
#  ['Игорь Конашенков', 'Сергей Рыжков'],
#  ['Шелдон Стейнбах'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Василий Голубев'],
#  ['Гари Олдман'],
#  [],
#  ['Николая Подгузова', 'Игорю Шувалову'],
#  [],
#  ['Андрея Аршавина'],
#  ['Джон Картер', 'Джон Картер', 'Джона Картера', 'Михаилом Галустяном'],
#  [],
#  ['Уэйн Рэттенбери'],
#  [],
#  ['Василий Лановой',
#   'Василий Лановой',
#   'Александр Розенбаум',
#   'Валентин Гафт',
#   'Владимир Гостюхин',
#   'Павел Лунгин',
#   'Карен Шахназаров'],
#  ['Колин Смит'],
#  ['экономклассе по', 'Владимир Путин', 'Алексей Улюкаев', 'Максим Соколов'],
#  ['Фрэнка Миллера', 'Лиамом Нисоном'],
#  [],
#  ['Эзекиэлем Хенти', 'Эзекиэля Хенти', 'Кирилл Котов'],
#  ['Роман Широков', 'Роман Широков', 'Василий Березуцкий', 'Юрий Жирков'],
#  [],
#  [],
#  [],
#  ['Дмитрий Медведев'],
#  ['Брайана Кеннеди'],
#  [],
#  ['Эдхам Акбулатов', 'Виктору Толоконскому'],
#  [],
#  ['Владимир Путин', 'Владимира Путина', 'Борис Титов', 'Аркадия Ротенберга'],
#  ['Геворк Абраамян', 'Михаил Багдасаров'],
#  ['Филип Бридлав', 'Сергей Кошелев', 'Филипом Бридлавом', 'Игорь Конашенков'],
#  ['из лоскутов'],
#  ['Абделькарим Мардини'],
#  [],
#  [],
#  ['Юра Мовсисян'],
#  ['Ангела Меркель'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Алексея Кузнецова', 'Алексей Кузнецов'],
#  ['Кевин Лав', 'Кевин Лав', 'Кевин Лав'],
#  ['Джеймса Бонда', 'Уильям Шекспир'],
#  ['Ноэль Галлахер',
#   'Ноэль Галлахер',
#   'Лиам Галлахер',
#   'Ноэль Галлахер',
#   'Ноэля брак'],
#  ['Михаил Валов', 'Максим Кузюк'],
#  ['Владимир Путин', 'Дмитрий Медведев'],
#  [],
#  ['Владимир Путин'],
#  [],
#  ['Стива Макларена'],
#  ['Анатолий Исайкин'],
#  [],
#  [],
#  [],
#  [],
#  ['Никите Михалкову', 'Иосиф Бойм', 'Альберт Баков'],
#  ['Сергей Новиков'],
#  ['Александра Морозова'],
#  [],
#  [],
#  ['Алишер Усманов', 'Николая Толстых'],
#  [],
#  [],
#  [],
#  ['Александра Поветкина',
#   'Владимиром Кличко',
#   'Андрей Рябинский',
#   'ВолодяВладимир Кличко',
#   'ПоветкинаСам Поветкин',
#   'Дмитрий Иванов'],
#  [],
#  ['Елены Вавиловой', 'Трэйси Ли', 'Андрея Безрукова'],
#  ['Артемия Лебедева', 'Артемия Лебедева'],
#  [],
#  [],
#  [],
#  ['августа по'],
#  ['Виктор Яценко'],
#  ['Максим Дылдин',
#   'Лев Мосин',
#   'Сергей Петухов',
#   'Владимир Краснов',
#   'Татьяны Лысенко',
#   'Александр Меньков'],
#  ['Хасана Закаева', 'Игорь Трунов', 'Шамиля Басаева', 'Гериханом Дудаевым'],
#  ['Владимир Путин'],
#  [],
#  ['Юрий Бицуев', 'Александра Полякова', 'Роберта Занкишиева'],
#  ['Анатолий Чубайс',
#   'премьерДмитрий Медведев',
#   'Герман Греф',
#   'Дмитрий Медведев'],
#  [],
#  [],
#  ['Сергей Родионов'],
#  ['Кристиан Атсу', 'Хамес Родригес'],
#  ['Дэвид Кэмерон', 'Марка Притчарда', 'Марк Притчард'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Гарика Сукачева', 'Евгения Евстигнеева', 'Гарик Сукачев'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Илья Чичкан'],
#  [],
#  [],
#  [],
#  [],
#  ['Дмитрием Медведевым'],
#  [],
#  [],
#  ['Виктора Мельниковых',
#   'Виктор Мельников',
#   'Виктора Мельникова',
#   'Константина Мельникова',
#   'Екатерина Каринская'],
#  ['Эшли Грин', 'Роберт Паттинсон'],
#  [],
#  ['Алана Шварца'],
#  [],
#  ['Владимира Путина', 'Алексей Миллер'],
#  ['Эллиотт Сеймур', 'Эллиотт Сеймур'],
#  ['Бернардо Бертолуччи'],
#  ['Игорь Сечин',
#   'Аксель Шпрингер',
#   'Игорь Сечин',
#   'Игорь Сечин',
#   'Владимир Сунгоркин',
#   'Андрей Костин',
#   'Алексей Миллер'],
#  ['Роман Абрамович'],
#  [],
#  [],
#  ['Эдуард Ставицкий'],
#  ['Павел Дуров', 'Дмитрий Сергеев'],
#  [],
#  [],
#  [],
#  ['Гарик Харламов', 'Гарик Харламов'],
#  [],
#  [],
#  [],
#  [],
#  ['Теллера по', 'Дэйв Франко', 'Логану Лерману', 'Кэтлин Кеннеди'],
#  ['Майкла Джексона', 'Майкла Джексона', 'Майкл Джексон'],
#  [],
#  [],
#  ['Майк Паркер'],
#  [],
#  [],
#  ...]

# %%
Birth_Date = fact(
    'BirthFact',
    ['birth_date']
)

DAY = and_(
    gte(1),
    lte(31)
)
MONTH = and_(
    gte(1),
    lte(12)
)
YEAR = and_(
    gte(1),
    lte(2030)
)
DATE = rule(
    YEAR,
    '-',
    MONTH,
    '-',
    DAY
)

MONTH = morph_pipeline([
    'январь',
    'февраль',
    'март',
    'апрель',
    'мая',
    'июнь',
    'июль',
    'август',
    'сентябрь',
    'октябрь',
    'ноябрь',
    'декабрь'
])

YEAR_WORDS = or_(
    rule(caseless('г'), '.'),
    rule(normalized('год'))
)
DATE = or_(
    rule(
        YEAR,
        '-',
        MONTH,
        '-',
        DAY
    ),
    rule(
        DAY.optional(),
        MONTH.optional(),
        YEAR,
        YEAR_WORDS.optional()
    )
)

BORN_WORD = morph_pipeline([
    'родился'])

BIRTH_DATE = rule(
    BORN_WORD,
    dictionary({'в'}).optional(),
    gram("NOUN").optional().repeatable(),
    dictionary({'в'}).optional(),
    DATE.interpretation(Birth_Date.birth_date)
).interpretation(Birth_Date)

# %%
parser_birth_date = Parser(BIRTH_DATE)

text_birth_date_found = []
with open(file_path, 'r', encoding='utf-8') as file:
    for text in file:
        birth_dates_found = []
        for match in parser_birth_date.findall(text):
            birth_date_fact = match.fact
            birth_dates_found.append(birth_date_fact.birth_date)
            print(birth_dates_found)
        text_birth_date_found.append(birth_dates_found)
text_birth_date_found
# Out:
# ['1926 году']
# ['1928 году']
# ['11 сентября 1865 года']
# ['25']
# ['2013 году']
# ['1935 году']
# ['5 марта 1992 года']
# ['1928 году']
# ['1938 году']
# ['1938 году', '1913 году']
# ['1928 году']
# ['1992 году']
# ['18 декабря 1937 года']
# ['7']
# ['1990 году']
# ['27 октября 1944 года']
# ['2010 году']
# ['1950 году']
# ['1941 году']
# ['24 ноября 1932 года']
# ['25 мая 1927 года']
# ['1984 году']
# ['1979 году']
# ['1841 году']
# ['22 июля 2013']
# ['13 марта 1988 года']
# ['13 марта 1988 года', '1967 году']
# ['1956 году']
# ['1953 году']
# ['1816 году']
# ['2012']
# ['1962 году']
# ['1979 году']
# ['1925 году']
# ['2007 году']
# ['2004 году']
# ['2012 года']
# ['1990 году']
# ['18 ноября 1927 года']
# ['1928 году']
# ['1928 году']
# ['1927 году']
# ['1928 году']
# ['1922 году']
# ['12 января 1936 года']
# ['1967 года']
# ['1834 году']
# ['июле 1904 года']
# ['2013']
# ['2013', '2012 году']
# ['12 декабря 1863 года']
# ['26 марта 2012 года']
# ['1917 году']
# ['17 апреля 1919 года']
# ['1932 году']
# ['1816 году']
# ['4 мая 1934 года']
# ['1930 году']
# ['1895 году']
# ['1938 году']
# ['мае 1984 года']
# ['1938 году']
# ['1969 году']
# ['2 июня 1974 года']
# ['15 октября 2005 года']
# ['11 марта 1989 года']
# ['1957 году']
# ['2005 году']
# ['мае 2004 года']
# ['1998']
# ['21 мая 1924 года']
# ['1923 году']
# ['7']
# ['2012 году']
# ['1961 году']
# ['26']
# ['1949 году']
# ['15 декабря 1907 года']
# ['27 августа 1959 года']
# ['5 августа 1930 года']
# ['3 февраля 1909 года']
# ['22 июля 2013 года']
# ['22 июля 2013 года', '22']
# ['1925 году']
# ['7 июля 1901 года']
# ['1967 году']
# ['23 декабря 1931 года']
# ['1971 году']
# ['1968 году']
# ['21 октября 1980 года']
# ['28 июня 1913 года']
# ['1933 году']
# ['31 августа 1989 года']
# ['1985 году']
# ['1940 году']
# ['11 мая 1720 года']
# ['1933 году']
# ['26 марта 1931 года']
# ['1 января 2014 года']
# ['21 мая 1937 года']
# ['1877 году']
# ['1988 году']
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['1926 году'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['1928 году'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
Birth_Place = fact(
    'BirthPlaceFact',
    ['birth_place']
)

PLACE_NAME = rule(
    gram('Geox').repeatable(max=2)
).interpretation(Birth_Place.birth_place)

PLACE_WORD = morph_pipeline([
    'город',
    'страна'
])

BIRTH_PLACE = rule(
    BORN_WORD,
    dictionary({'в'}).optional(),
    DATE.optional(),
    dictionary({'в'}),
    PLACE_WORD.optional(), 
    PLACE_NAME
).interpretation(Birth_Place)

# %%
parser_birth_place = Parser(BIRTH_PLACE)

text_birth_places_found = []
with open(file_path, 'r', encoding='utf-8') as file:
    for text in file:
        birth_places_found = []
        for match in parser_birth_place.findall(text):
            birth_place_fact = match.fact
            birth_places_found.append(birth_place_fact.birth_place)
            print(birth_places_found)
        text_birth_places_found.append(birth_places_found)
text_birth_places_found
# Out:
# ['Сиэтле']
# ['США']
# ['Севастополе']
# ['Грузии']
# ['Польше']
# ['Польше']
# ['Калифорнии']
# ['Артемовске']
# ['Лондоне']
# ['США']
# ['Токио']
# ['Москве']
# ['Калининграде']
# ['Москве']
# ['Львове']
# ['Сочи']
# ['Массачусетсе']
# ['Ростове']
# ['США']
# ['Рочестере']
# ['Самаре']
# ['Баку']
# ['ЮАР']
# ['Лондоне']
# ['Риге']
# ['Каннах']
# ['Мексике']
# ['Ливане']
# ['США']
# ['Сальск']
# ['Ленинграде']
# ['США']
# ['Ленинграде']
# ['мае']
# ['Москве']
# ['Ленинграде']
# ['Фатеж']
# ['Копенгагене']
# ['Ленинграде']
# ['мае']
# ['Смоленске']
# ['России']
# ['Ливерпуле']
# ['Витебске']
# ['Риге']
# ['Риге', 'Братиславе']
# ['Саратове']
# ['Лондоне']
# ['Сарапуле']
# ['Кемерово']
# ['Индии']
# ['Косово']
# ['Москве']
# ['Грозном']
# ['Красноярске']
# ['Бостоне']
# ['Кирове']
# ['Москве']
# ['Омске']
# ['Индии']
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Сиэтле'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['США'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Севастополе'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Грузии'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Польше'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
@dataclass
class Entry:
    name: str
    birth_date: Optional[str]
    birth_place: Optional[str]

extracted_entries = []

# %%
def align_to_first_size(main_list, *other_lists):
    target_size = len(main_list)
    aligned_lists = []
    
    for lst in other_lists:
        if len(lst) < target_size:
            aligned_lists.append(lst + [None] * (target_size - len(lst)))
        else:
            aligned_lists.append(lst[:target_size])
    return aligned_lists

# %%
text_names_found
text_birth_places_found
text_birth_date_found
for names, birth_places, birth_dates in zip(text_names_found, text_birth_places_found, text_birth_date_found):
    aligned_birth_places, aligned_birth_dates = align_to_first_size(names, birth_places, birth_dates)
    for name, birth_place, birth_dates in zip(names, aligned_birth_places, aligned_birth_dates):
        print(Entry(name, birth_dates, birth_place))
# Out:
# Entry(name='Матс Сундин', birth_date=None, birth_place=None)
# Entry(name='Матс Сундин', birth_date=None, birth_place=None)
# Entry(name='Владимир Филиппов', birth_date=None, birth_place=None)
# Entry(name='Ильгизу Фахриеву', birth_date=None, birth_place=None)
# Entry(name='Михаилом Прохоровым', birth_date=None, birth_place=None)
# Entry(name='Бена Николсона', birth_date=None, birth_place=None)
# Entry(name='Анри Матисса', birth_date=None, birth_place=None)
# Entry(name='Пабло Пикассо', birth_date=None, birth_place=None)
# Entry(name='Жоржа Брака', birth_date=None, birth_place=None)
# Entry(name='Владимиром Путиным', birth_date=None, birth_place=None)
# Entry(name='Леонида Брежнева', birth_date=None, birth_place=None)
# Entry(name='Юрий Андропов', birth_date=None, birth_place=None)
# Entry(name='Игоря Денисова', birth_date=None, birth_place=None)
# Entry(name='Игорь Денисов', birth_date=None, birth_place=None)
# Entry(name='Ларри Гагосян', birth_date=None, birth_place=None)
# Entry(name='Виктор Пинчук', birth_date=None, birth_place=None)
# Entry(name='Марину Абрамович', birth_date=None, birth_place=None)
# Entry(name='Энди Коулсон', birth_date=None, birth_place=None)
# Entry(name='Руперта Мердока', birth_date=None, birth_place=None)
# Entry(name='Энди Коулсона', birth_date=None, birth_place=None)
# Entry(name='из еврокубковАрмейский', birth_date=None, birth_place=None)
# Entry(name='Леонида Слуцкого', birth_date=None, birth_place=None)
# Entry(name='Юлия Александрова', birth_date=None, birth_place=None)
# Entry(name='Елена Валюшкина', birth_date=None, birth_place=None)
# Entry(name='Валентина Мазулина', birth_date=None, birth_place=None)
# Entry(name='Андрея Першина', birth_date=None, birth_place=None)
# Entry(name='Игорь Артемьев', birth_date=None, birth_place=None)
# Entry(name='Эльвира Набиуллина', birth_date=None, birth_place=None)
# Entry(name='Михаил Сухов', birth_date=None, birth_place=None)
# Entry(name='Владимиром Путиным', birth_date=None, birth_place=None)
# Entry(name='Владимир Долинский', birth_date=None, birth_place=None)
# Entry(name='Марина Могилевская', birth_date=None, birth_place=None)
# Entry(name='Анна Терехова', birth_date=None, birth_place=None)
# Entry(name='Юрий Чайка', birth_date=None, birth_place=None)
# Entry(name='Александру Бастрыкину', birth_date=None, birth_place=None)
# Entry(name='Дениса Вороненкова', birth_date=None, birth_place=None)
# Entry(name='Отари Кобахидзе', birth_date=None, birth_place=None)
# Entry(name='Майкла Джексона', birth_date=None, birth_place=None)
# Entry(name='Ева Польна', birth_date=None, birth_place=None)
# Entry(name='Майкл Джексон', birth_date=None, birth_place=None)
# Entry(name='Хайо Зеппельт', birth_date=None, birth_place=None)
# Entry(name='Ольга Скабеева', birth_date=None, birth_place=None)
# Entry(name='матчМария Шарапова', birth_date=None, birth_place=None)
# Entry(name='Григорий Родченков', birth_date=None, birth_place=None)
# Entry(name='Наталью Желанову', birth_date=None, birth_place=None)
# Entry(name='Вера Брежнева', birth_date=None, birth_place=None)
# Entry(name='Сергей Косырев', birth_date=None, birth_place=None)
# Entry(name='Дмитрия Циликина', birth_date=None, birth_place=None)
# Entry(name='марта Косырев', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Циликин', birth_date=None, birth_place=None)
# Entry(name='Вагит Алекперов', birth_date=None, birth_place=None)
# Entry(name='Вагит Алекперов', birth_date=None, birth_place=None)
# Entry(name='Джастин Грэй', birth_date=None, birth_place=None)
# Entry(name='Сида Вишеса', birth_date=None, birth_place=None)
# Entry(name='Сидом Вишесом', birth_date=None, birth_place=None)
# Entry(name='Саймон Ричи', birth_date=None, birth_place=None)
# Entry(name='Алана Паркера', birth_date=None, birth_place=None)
# Entry(name='Сида Вишеса', birth_date=None, birth_place=None)
# Entry(name='Сид Вишес', birth_date=None, birth_place=None)
# Entry(name='Александр Шпрыгин', birth_date=None, birth_place=None)
# Entry(name='Марку Цукербергу', birth_date=None, birth_place=None)
# Entry(name='Борис Гребенщиков', birth_date=None, birth_place=None)
# Entry(name='Борис Гребенщиков', birth_date=None, birth_place=None)
# Entry(name='Джеки Смит', birth_date=None, birth_place=None)
# Entry(name='Джеки Смит', birth_date=None, birth_place=None)
# Entry(name='Джеки Смит', birth_date=None, birth_place=None)
# Entry(name='Галину Немову', birth_date=None, birth_place=None)
# Entry(name='Алексея Немова', birth_date=None, birth_place=None)
# Entry(name='Галина Немова', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Чугунов', birth_date=None, birth_place=None)
# Entry(name='Петер Вестербака', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Песков', birth_date=None, birth_place=None)
# Entry(name='Виктора Кирьянова', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Комбаровы', birth_date=None, birth_place=None)
# Entry(name='Денис Глушаков', birth_date=None, birth_place=None)
# Entry(name='Евгений Макеев', birth_date=None, birth_place=None)
# Entry(name='Сергей Паршивлюк', birth_date=None, birth_place=None)
# Entry(name='Юра Мовсисян', birth_date=None, birth_place=None)
# Entry(name='Романом Широковым', birth_date=None, birth_place=None)
# Entry(name='Дмитрия Аленичева', birth_date=None, birth_place=None)
# Entry(name='Кирилла Комбарова', birth_date=None, birth_place=None)
# Entry(name='Андрей Голубков', birth_date=None, birth_place=None)
# Entry(name='Джозефа Киттингера', birth_date=None, birth_place=None)
# Entry(name='Поля Сезанна', birth_date=None, birth_place=None)
# Entry(name='Поля Сезанна', birth_date=None, birth_place=None)
# Entry(name='Огюста Ренуара', birth_date=None, birth_place=None)
# Entry(name='Анри Матисса', birth_date=None, birth_place=None)
# Entry(name='Пабло Пикассо', birth_date=None, birth_place=None)
# Entry(name='Эдгара Дега', birth_date=None, birth_place=None)
# Entry(name='Клода Моне', birth_date=None, birth_place=None)
# Entry(name='Джанет Джексон', birth_date=None, birth_place=None)
# Entry(name='Джанет Джексон', birth_date=None, birth_place=None)
# Entry(name='Джанет Джексон', birth_date=None, birth_place=None)
# Entry(name='Джанет Джексон', birth_date=None, birth_place=None)
# Entry(name='Джанет Джексон', birth_date=None, birth_place=None)
# Entry(name='Майкл Джексон', birth_date=None, birth_place=None)
# Entry(name='Джанет Джексон', birth_date=None, birth_place=None)
# Entry(name='Сара Полсон', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Песков', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Рогозин', birth_date=None, birth_place=None)
# Entry(name='Сергей Шойгу', birth_date=None, birth_place=None)
# Entry(name='Валерий Герасимов', birth_date=None, birth_place=None)
# Entry(name='Юрий Борисов', birth_date=None, birth_place=None)
# Entry(name='Игорь Комаров', birth_date=None, birth_place=None)
# Entry(name='Андрея Мельниченко', birth_date=None, birth_place=None)
# Entry(name='Филипп Старк', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Теунис Тенбрук', birth_date=None, birth_place=None)
# Entry(name='Теунис Тенбрук', birth_date=None, birth_place=None)
# Entry(name='Теуниса Тенбрука', birth_date=None, birth_place=None)
# Entry(name='Алексей Кудрин', birth_date=None, birth_place=None)
# Entry(name='Алексей Кудрин', birth_date=None, birth_place=None)
# Entry(name='Льва Яшина', birth_date=None, birth_place=None)
# Entry(name='Льва Яшина', birth_date=None, birth_place=None)
# Entry(name='Карен Оганесян', birth_date=None, birth_place=None)
# Entry(name='Максим Матвеев', birth_date=None, birth_place=None)
# Entry(name='Валерии Харламове', birth_date=None, birth_place=None)
# Entry(name='Льву Яшину', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Дени Мирзоева', birth_date=None, birth_place=None)
# Entry(name='Авдотьи Смирновой', birth_date=None, birth_place=None)
# Entry(name='Алексея Сидорова', birth_date=None, birth_place=None)
# Entry(name='Олега Погодина', birth_date=None, birth_place=None)
# Entry(name='Карена Оганесяна', birth_date=None, birth_place=None)
# Entry(name='Алены Званцовой', birth_date=None, birth_place=None)
# Entry(name='Кевин Бейтс', birth_date=None, birth_place=None)
# Entry(name='Кевина Бейтса', birth_date=None, birth_place=None)
# Entry(name='Алексей Пажитнов', birth_date=None, birth_place=None)
# Entry(name='Дункана Брауна', birth_date=None, birth_place=None)
# Entry(name='Брюс Робертсон', birth_date=None, birth_place=None)
# Entry(name='Лидию Рыхлову', birth_date=None, birth_place=None)
# Entry(name='Дмитрию Рогозину', birth_date=None, birth_place=None)
# Entry(name='Владимира Липунова', birth_date=None, birth_place=None)
# Entry(name='Сергей Дарькин', birth_date=None, birth_place=None)
# Entry(name='Роджер Уотерс', birth_date=None, birth_place=None)
# Entry(name='Роджер Уотерс', birth_date=None, birth_place=None)
# Entry(name='Дэвид Гилмор', birth_date=None, birth_place=None)
# Entry(name='Ник Мейсон', birth_date=None, birth_place=None)
# Entry(name='Мария Захарова', birth_date=None, birth_place=None)
# Entry(name='Сергей Стрельбицкий', birth_date=None, birth_place=None)
# Entry(name='Расселу Кроу', birth_date=None, birth_place=None)
# Entry(name='Расселу Кроу', birth_date=None, birth_place=None)
# Entry(name='Василий Быков', birth_date=None, birth_place=None)
# Entry(name='Василий Быков', birth_date=None, birth_place=None)
# Entry(name='Василий Быков', birth_date=None, birth_place=None)
# Entry(name='Леонарда Эйлера', birth_date=None, birth_place=None)
# Entry(name='Пафнутием Чебышевым', birth_date=None, birth_place=None)
# Entry(name='Георгом Риманом', birth_date=None, birth_place=None)
# Entry(name='Григорием Перельманом', birth_date=None, birth_place=None)
# Entry(name='Джеймса Кэмерона', birth_date=None, birth_place=None)
# Entry(name='Марк Цукерберг', birth_date=None, birth_place=None)
# Entry(name='из титрова', birth_date=None, birth_place=None)
# Entry(name='Авдотья Смирнова', birth_date=None, birth_place=None)
# Entry(name='Гарри Поттер', birth_date=None, birth_place=None)
# Entry(name='Билл Мюррей', birth_date=None, birth_place=None)
# Entry(name='Джон Гудман', birth_date=None, birth_place=None)
# Entry(name='Джош Холлоуэй', birth_date=None, birth_place=None)
# Entry(name='Никиты Хрущева', birth_date=None, birth_place=None)
# Entry(name='Сергея Королева', birth_date=None, birth_place=None)
# Entry(name='Джон Ангер', birth_date=None, birth_place=None)
# Entry(name='Джон Ангер', birth_date=None, birth_place=None)
# Entry(name='Джон Ангер', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Муратов', birth_date=None, birth_place=None)
# Entry(name='Мэтт Смит', birth_date=None, birth_place=None)
# Entry(name='Брент Сибрук', birth_date=None, birth_place=None)
# Entry(name='Джеффа Картера', birth_date=None, birth_place=None)
# Entry(name='Вячеслав Войнов', birth_date=None, birth_place=None)
# Entry(name='Лиама Галлахера', birth_date=None, birth_place=None)
# Entry(name='Лиам Галлахер', birth_date=None, birth_place=None)
# Entry(name='Руперта Мердока', birth_date=None, birth_place=None)
# Entry(name='Крэйг Райт', birth_date=None, birth_place=None)
# Entry(name='Василий Баранов', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Ивана Таврина', birth_date=None, birth_place=None)
# Entry(name='Алишера Усманова', birth_date=None, birth_place=None)
# Entry(name='Александр Невзоров', birth_date=None, birth_place=None)
# Entry(name='Валентины Матвиенко', birth_date=None, birth_place=None)
# Entry(name='Александра Невзорова', birth_date=None, birth_place=None)
# Entry(name='Александра Невзорова', birth_date=None, birth_place=None)
# Entry(name='Александр Невзоров', birth_date=None, birth_place=None)
# Entry(name='Оливер Экман', birth_date=None, birth_place=None)
# Entry(name='Антон Худобин', birth_date=None, birth_place=None)
# Entry(name='Сергей Плотников', birth_date=None, birth_place=None)
# Entry(name='Сергей Мозякин', birth_date=None, birth_place=None)
# Entry(name='Александр Попов', birth_date=None, birth_place=None)
# Entry(name='Олега Знарка', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Игорь Шувалов', birth_date=None, birth_place=None)
# Entry(name='Андрей Белоусов', birth_date=None, birth_place=None)
# Entry(name='Джульетта Старлинг', birth_date=None, birth_place=None)
# Entry(name='Кристиан Шмидт', birth_date=None, birth_place=None)
# Entry(name='Николаем Федоровым', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Владимира Нестерова', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Владимира Поповкина', birth_date=None, birth_place=None)
# Entry(name='Владимиром Путиным', birth_date=None, birth_place=None)
# Entry(name='Дмитрием Медведевым', birth_date=None, birth_place=None)
# Entry(name='Яков Силин', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Арсений Яценюк', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Песков', birth_date=None, birth_place=None)
# Entry(name='Наталья Яресько', birth_date=None, birth_place=None)
# Entry(name='Николая Жердева', birth_date=None, birth_place=None)
# Entry(name='Томми Ли', birth_date=None, birth_place=None)
# Entry(name='Томми Ли', birth_date=None, birth_place=None)
# Entry(name='Крис Купер', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Кристин Райт', birth_date=None, birth_place=None)
# Entry(name='Муаммаром Каддафи', birth_date=None, birth_place=None)
# Entry(name='Муаммара Каддафи', birth_date=None, birth_place=None)
# Entry(name='Александр Грушко', birth_date=None, birth_place=None)
# Entry(name='Федор Лукьянов', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Анджея Сапковского', birth_date=None, birth_place=None)
# Entry(name='Романа Терюшкова', birth_date=None, birth_place=None)
# Entry(name='Стивен Уилсон', birth_date=None, birth_place=None)
# Entry(name='Аркадий Ткачук', birth_date=None, birth_place=None)
# Entry(name='Георгий Перский', birth_date=None, birth_place=None)
# Entry(name='Аркадий Ткачук', birth_date=None, birth_place=None)
# Entry(name='Ксении Собчак', birth_date=None, birth_place=None)
# Entry(name='Ксенией Собчак', birth_date=None, birth_place=None)
# Entry(name='Борис Немцов', birth_date=None, birth_place=None)
# Entry(name='Алексей Навальный', birth_date=None, birth_place=None)
# Entry(name='Ксения Собчак', birth_date=None, birth_place=None)
# Entry(name='Ксения Собчак', birth_date=None, birth_place=None)
# Entry(name='Ксения Собчак', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Мишель Обама', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Джош Сингер', birth_date=None, birth_place=None)
# Entry(name='Адольфа Гитлера', birth_date=None, birth_place=None)
# Entry(name='Нил Мориц', birth_date=None, birth_place=None)
# Entry(name='Валерий Ничушкин', birth_date=None, birth_place=None)
# Entry(name='Александр Хохлачев', birth_date=None, birth_place=None)
# Entry(name='Кирилл Дьяков', birth_date=None, birth_place=None)
# Entry(name='Михаил Григоренко', birth_date=None, birth_place=None)
# Entry(name='Олега Пешкова', birth_date=None, birth_place=None)
# Entry(name='Олега Пешкова', birth_date=None, birth_place=None)
# Entry(name='Виктор Бондарев', birth_date=None, birth_place=None)
# Entry(name='Олег Королев', birth_date=None, birth_place=None)
# Entry(name='Олег Пешков', birth_date=None, birth_place=None)
# Entry(name='Константин Мурахтин', birth_date=None, birth_place=None)
# Entry(name='Вагит Алекперов', birth_date=None, birth_place=None)
# Entry(name='Арнольдом Шварценеггером', birth_date=None, birth_place='Сиэтле')
# Entry(name='Валон Бериша', birth_date=None, birth_place=None)
# Entry(name='Сергей Ковалев', birth_date=None, birth_place=None)
# Entry(name='Петр Лукьянов', birth_date=None, birth_place=None)
# Entry(name='Юрием Добровольским', birth_date=None, birth_place=None)
# Entry(name='Сергеем Нефедкиным', birth_date=None, birth_place=None)
# Entry(name='Данилой Шапошниковым', birth_date=None, birth_place=None)
# Entry(name='Петром Лукьяновым', birth_date=None, birth_place=None)
# Entry(name='Ольгой Маслиховой', birth_date=None, birth_place=None)
# Entry(name='Алексея Навального', birth_date=None, birth_place=None)
# Entry(name='Никиты Белых', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Альбрехта Дюрера', birth_date=None, birth_place=None)
# Entry(name='В Истборне', birth_date=None, birth_place=None)
# Entry(name='Даниэль Баренбойм', birth_date=None, birth_place=None)
# Entry(name='Анна Нетребко', birth_date=None, birth_place=None)
# Entry(name='Амадеем Моцартом', birth_date=None, birth_place=None)
# Entry(name='Луиджи Манцотти', birth_date=None, birth_place=None)
# Entry(name='Майкла Джексона', birth_date=None, birth_place=None)
# Entry(name='Майкла Джексона', birth_date=None, birth_place=None)
# Entry(name='Майкл Джексон', birth_date=None, birth_place=None)
# Entry(name='Марка Цукерберга', birth_date=None, birth_place=None)
# Entry(name='Николя Саркози', birth_date=None, birth_place=None)
# Entry(name='Руперта Мердока', birth_date=None, birth_place=None)
# Entry(name='Руперт Мердок', birth_date=None, birth_place=None)
# Entry(name='Джеймса Бонда', birth_date=None, birth_place=None)
# Entry(name='Джеймса Бонда', birth_date=None, birth_place=None)
# Entry(name='Джеймсе Бонде', birth_date=None, birth_place=None)
# Entry(name='Олег Груненков', birth_date=None, birth_place=None)
# Entry(name='Наполеоном Бонапартом', birth_date=None, birth_place=None)
# Entry(name='Николая Азарова', birth_date=None, birth_place=None)
# Entry(name='Элвиса Пресли', birth_date=None, birth_place=None)
# Entry(name='Элвиса Пресли', birth_date=None, birth_place=None)
# Entry(name='Ричардом Никсоном', birth_date=None, birth_place=None)
# Entry(name='Вячеслав Першуков', birth_date=None, birth_place=None)
# Entry(name='Андрей Говердовский', birth_date=None, birth_place=None)
# Entry(name='из городов', birth_date=None, birth_place=None)
# Entry(name='Михаила Глущенко', birth_date=None, birth_place=None)
# Entry(name='Галины Старовойтовой', birth_date=None, birth_place=None)
# Entry(name='Владимира Барсукова', birth_date=None, birth_place=None)
# Entry(name='Галина Старовойтова', birth_date=None, birth_place=None)
# Entry(name='Андрей Белоусов', birth_date=None, birth_place=None)
# Entry(name='Михаила Ходорковского', birth_date=None, birth_place=None)
# Entry(name='Юрий Бойко', birth_date=None, birth_place=None)
# Entry(name='Илью Ковальчука', birth_date=None, birth_place=None)
# Entry(name='Станислав Галимов', birth_date=None, birth_place=None)
# Entry(name='Эмиль Гарипов', birth_date=None, birth_place=None)
# Entry(name='Александр Еременко', birth_date=None, birth_place=None)
# Entry(name='Михаил Григорьев', birth_date=None, birth_place=None)
# Entry(name='Денис Денисов', birth_date=None, birth_place=None)
# Entry(name='Никита Зайцев', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Калинин', birth_date=None, birth_place=None)
# Entry(name='Евгений Рясенский', birth_date=None, birth_place=None)
# Entry(name='Глеб Корягин', birth_date=None, birth_place=None)
# Entry(name='Андрей Миронов', birth_date=None, birth_place=None)
# Entry(name='Александр Кутузов', birth_date=None, birth_place=None)
# Entry(name='Евгений Медведев', birth_date=None, birth_place=None)
# Entry(name='Илья Никулин', birth_date=None, birth_place=None)
# Entry(name='Александр Бурмистров', birth_date=None, birth_place=None)
# Entry(name='Михаил Варнаков', birth_date=None, birth_place=None)
# Entry(name='Кирилл Петров', birth_date=None, birth_place=None)
# Entry(name='Владимир Глазулин', birth_date=None, birth_place=None)
# Entry(name='Антон Глинкин', birth_date=None, birth_place=None)
# Entry(name='Евгений Дадонов', birth_date=None, birth_place=None)
# Entry(name='Илья Зубов', birth_date=None, birth_place=None)
# Entry(name='Сергей Калинин', birth_date=None, birth_place=None)
# Entry(name='Сергей Широков', birth_date=None, birth_place=None)
# Entry(name='Максим Карпов', birth_date=None, birth_place=None)
# Entry(name='Максим Пестушко', birth_date=None, birth_place=None)
# Entry(name='Илья Ковальчук', birth_date=None, birth_place=None)
# Entry(name='Артемий Панарин', birth_date=None, birth_place=None)
# Entry(name='Виктор Тихонов', birth_date=None, birth_place=None)
# Entry(name='Евгений Шипачев', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Кугрышев', birth_date=None, birth_place=None)
# Entry(name='Николай Прохоркин', birth_date=None, birth_place=None)
# Entry(name='Федор Малыхин', birth_date=None, birth_place=None)
# Entry(name='Виктора Януковича', birth_date=None, birth_place=None)
# Entry(name='Юрий Чайка', birth_date=None, birth_place=None)
# Entry(name='Алексей Ведев', birth_date=None, birth_place=None)
# Entry(name='Константином Мурахтиным', birth_date=None, birth_place=None)
# Entry(name='Игорь Конашенков', birth_date=None, birth_place=None)
# Entry(name='Олег Пешков', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Алексея Улюкаева', birth_date=None, birth_place=None)
# Entry(name='Алексей Улюкаев', birth_date=None, birth_place=None)
# Entry(name='Владимиру Путину', birth_date=None, birth_place=None)
# Entry(name='Джона Леннона', birth_date=None, birth_place=None)
# Entry(name='Виктор Лысенко', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Панкин', birth_date=None, birth_place=None)
# Entry(name='Сергей Лазарев', birth_date=None, birth_place=None)
# Entry(name='Филипп Киркоров', birth_date=None, birth_place=None)
# Entry(name='В Московском', birth_date=None, birth_place=None)
# Entry(name='Ольгу Гореловскую', birth_date=None, birth_place=None)
# Entry(name='Баннинга Кока', birth_date=None, birth_place=None)
# Entry(name='Джанни Инфантино', birth_date=None, birth_place=None)
# Entry(name='Владислав Масалов', birth_date=None, birth_place=None)
# Entry(name='Владислав Масалов', birth_date=None, birth_place=None)
# Entry(name='Айдан Салаховой', birth_date=None, birth_place=None)
# Entry(name='Ильхам Алиев', birth_date=None, birth_place=None)
# Entry(name='Айдан Салаховой', birth_date=None, birth_place=None)
# Entry(name='Юрий Аввакумов', birth_date=None, birth_place=None)
# Entry(name='Айдан Салаховой', birth_date=None, birth_place=None)
# Entry(name='Айдан Салахова', birth_date=None, birth_place=None)
# Entry(name='Елена Исинбаева', birth_date=None, birth_place=None)
# Entry(name='Анна Чичерова', birth_date=None, birth_place=None)
# Entry(name='Елена Слесаренко', birth_date=None, birth_place=None)
# Entry(name='Татьяна Лысенко', birth_date=None, birth_place=None)
# Entry(name='Юлия Зарипова', birth_date=None, birth_place=None)
# Entry(name='Мария Савинова', birth_date=None, birth_place=None)
# Entry(name='Юлия Гущина', birth_date=None, birth_place=None)
# Entry(name='Елена Лашманова', birth_date=None, birth_place=None)
# Entry(name='Ольга Каниськина', birth_date=None, birth_place=None)
# Entry(name='Иван Ухов', birth_date=None, birth_place=None)
# Entry(name='Юрий Борзаковский', birth_date=None, birth_place=None)
# Entry(name='Сергей Кирдяпкин', birth_date=None, birth_place=None)
# Entry(name='Татьяна Лебедева', birth_date=None, birth_place=None)
# Entry(name='Максима Кашулинского', birth_date=None, birth_place=None)
# Entry(name='Александр Винокуров', birth_date=None, birth_place=None)
# Entry(name='Николя Саркози', birth_date=None, birth_place=None)
# Entry(name='Владимир Якунин', birth_date=None, birth_place=None)
# Entry(name='Максим Соколов', birth_date=None, birth_place=None)
# Entry(name='Владимир Якунин', birth_date=None, birth_place=None)
# Entry(name='Сильвио Берлускони', birth_date=None, birth_place=None)
# Entry(name='Сильвио Берлускони', birth_date=None, birth_place=None)
# Entry(name='Дженна Джеймсон', birth_date=None, birth_place=None)
# Entry(name='Саша Грей', birth_date=None, birth_place=None)
# Entry(name='Евгений Савченко', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Владимир Жириновский', birth_date=None, birth_place=None)
# Entry(name='Александра Зубкова', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Труненков', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Гуджоян', birth_date=None, birth_place=None)
# Entry(name='Олег Бударгин', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Джессика Симпсон', birth_date=None, birth_place=None)
# Entry(name='Джессика Симпсон', birth_date=None, birth_place=None)
# Entry(name='Лизанн Фальк', birth_date=None, birth_place=None)
# Entry(name='Владимира Кличко', birth_date=None, birth_place=None)
# Entry(name='Владимира КличкоФьюри', birth_date=None, birth_place=None)
# Entry(name='Владимир Кличко', birth_date=None, birth_place=None)
# Entry(name='Фредди Крюгера', birth_date=None, birth_place=None)
# Entry(name='Юэль Киннаман', birth_date=None, birth_place=None)
# Entry(name='Гэри Олдман', birth_date=None, birth_place=None)
# Entry(name='Хью Лори', birth_date=None, birth_place=None)
# Entry(name='Фредди Крюгера', birth_date=None, birth_place=None)
# Entry(name='Михаила Гуцериева', birth_date=None, birth_place=None)
# Entry(name='Алихан Гуцериев', birth_date=None, birth_place=None)
# Entry(name='Алихан Гуцериев', birth_date=None, birth_place=None)
# Entry(name='Михаила Гуцериева', birth_date=None, birth_place=None)
# Entry(name='Алихан Гуцериев', birth_date=None, birth_place=None)
# Entry(name='Михаил Гуцериев', birth_date=None, birth_place=None)
# Entry(name='Бенедикт Хэнкок', birth_date=None, birth_place=None)
# Entry(name='Александр Петров', birth_date=None, birth_place=None)
# Entry(name='Евгением Плющенко', birth_date=None, birth_place=None)
# Entry(name='ли Ромни', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Брюс Дикинсон', birth_date=None, birth_place=None)
# Entry(name='Майкла Дугласа', birth_date=None, birth_place=None)
# Entry(name='Майкл Дуглас', birth_date=None, birth_place=None)
# Entry(name='Стив Харрис', birth_date=None, birth_place=None)
# Entry(name='Пола Верховена', birth_date=None, birth_place=None)
# Entry(name='Сергей Шубенков', birth_date=None, birth_place=None)
# Entry(name='Дарья Клишина', birth_date=None, birth_place=None)
# Entry(name='Кубрат Пулев', birth_date=None, birth_place=None)
# Entry(name='Владимиром Кличко', birth_date=None, birth_place=None)
# Entry(name='Андрея Зализняка', birth_date=None, birth_place=None)
# Entry(name='Рэнди Гербера', birth_date=None, birth_place=None)
# Entry(name='Александра Овечкина', birth_date=None, birth_place=None)
# Entry(name='Евгением Малкиным', birth_date=None, birth_place=None)
# Entry(name='Джейсон Рубин', birth_date=None, birth_place=None)
# Entry(name='Джейсон Рубин', birth_date=None, birth_place=None)
# Entry(name='цвет по', birth_date=None, birth_place=None)
# Entry(name='Джанни Инфантино', birth_date=None, birth_place=None)
# Entry(name='Джанни Инфантино', birth_date=None, birth_place=None)
# Entry(name='Павел Хамидулин', birth_date=None, birth_place=None)
# Entry(name='из Тюбингенского', birth_date=None, birth_place=None)
# Entry(name='Илья Ткаченко', birth_date=None, birth_place=None)
# Entry(name='Екатериной Рязановой', birth_date=None, birth_place=None)
# Entry(name='Алексей Горшков', birth_date=None, birth_place=None)
# Entry(name='Мерил Дэвис', birth_date=None, birth_place=None)
# Entry(name='Чарли Уайт', birth_date=None, birth_place=None)
# Entry(name='Елена Ильиных', birth_date=None, birth_place=None)
# Entry(name='Екатерина Боброва', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Соловьев', birth_date=None, birth_place=None)
# Entry(name='Джоэл Коэны', birth_date=None, birth_place=None)
# Entry(name='Джоэл Коэны', birth_date=None, birth_place=None)
# Entry(name='Тони Блэр', birth_date=None, birth_place=None)
# Entry(name='Бориса Грызлова', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Грызлов', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Грызлов', birth_date=None, birth_place=None)
# Entry(name='Дмитрия Грызлова', birth_date=None, birth_place=None)
# Entry(name='Джеймс Уильямсон', birth_date=None, birth_place=None)
# Entry(name='Ирина Тюрина', birth_date=None, birth_place=None)
# Entry(name='Сергея Швецова', birth_date=None, birth_place=None)
# Entry(name='ли Каплан', birth_date=None, birth_place=None)
# Entry(name='Ричарда Макларена', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Козак', birth_date=None, birth_place=None)
# Entry(name='Искандара Махмудова', birth_date=None, birth_place=None)
# Entry(name='Владимира Потанина', birth_date=None, birth_place=None)
# Entry(name='Владимир Поповкин', birth_date=None, birth_place=None)
# Entry(name='Владимир Поповкин', birth_date=None, birth_place=None)
# Entry(name='Захар Прилепин', birth_date=None, birth_place=None)
# Entry(name='Захар Прилепин', birth_date=None, birth_place=None)
# Entry(name='Михаила Тарковского', birth_date=None, birth_place=None)
# Entry(name='Евгения Водолазкина', birth_date=None, birth_place=None)
# Entry(name='Владимира Маяковского', birth_date=None, birth_place=None)
# Entry(name='Лилии Брик', birth_date=None, birth_place=None)
# Entry(name='Алексея Навального', birth_date=None, birth_place=None)
# Entry(name='Константина Янкаускаса', birth_date=None, birth_place=None)
# Entry(name='Ольга Горелик', birth_date=None, birth_place=None)
# Entry(name='Константин Янкаускас', birth_date=None, birth_place=None)
# Entry(name='Алексея Навального', birth_date=None, birth_place=None)
# Entry(name='Владимир Ашурков', birth_date=None, birth_place=None)
# Entry(name='Николай Ляскин', birth_date=None, birth_place=None)
# Entry(name='Константин Янкаускас', birth_date=None, birth_place=None)
# Entry(name='Владимир Ашурков', birth_date=None, birth_place=None)
# Entry(name='Николай Ляскин', birth_date=None, birth_place=None)
# Entry(name='Юрия Лужкова', birth_date=None, birth_place=None)
# Entry(name='Владимиру Путину', birth_date=None, birth_place=None)
# Entry(name='Леонида Гозмана', birth_date=None, birth_place=None)
# Entry(name='Бориса Немцова', birth_date=None, birth_place=None)
# Entry(name='из Эксетерского', birth_date=None, birth_place=None)
# Entry(name='Сергея Румянцева', birth_date=None, birth_place=None)
# Entry(name='Артур Анишин', birth_date=None, birth_place=None)
# Entry(name='Юрия Валуева', birth_date=None, birth_place=None)
# Entry(name='Салаватом Юлаевым', birth_date=None, birth_place=None)
# Entry(name='Сергея Полонского', birth_date=None, birth_place=None)
# Entry(name='Дмитрию Луценко', birth_date=None, birth_place=None)
# Entry(name='Тима Бертона', birth_date=None, birth_place=None)
# Entry(name='Джейсон Шварцман', birth_date=None, birth_place=None)
# Entry(name='Джин Сперлинг', birth_date=None, birth_place=None)
# Entry(name='Барака Обамы', birth_date=None, birth_place=None)
# Entry(name='В киберпанковой', birth_date=None, birth_place=None)
# Entry(name='Майка Пондсмита', birth_date=None, birth_place=None)
# Entry(name='Евгений Гинер', birth_date=None, birth_place=None)
# Entry(name='Николай Толстых', birth_date=None, birth_place=None)
# Entry(name='Александр Маркин', birth_date=None, birth_place=None)
# Entry(name='Мария Шарапова', birth_date=None, birth_place=None)
# Entry(name='Мария Шарапова', birth_date=None, birth_place=None)
# Entry(name='Семен Елистратов', birth_date=None, birth_place=None)
# Entry(name='Екатерина Боброва', birth_date=None, birth_place=None)
# Entry(name='Александр Маркин', birth_date=None, birth_place=None)
# Entry(name='Юрий Иванов', birth_date=None, birth_place=None)
# Entry(name='Юрий Иванов', birth_date=None, birth_place=None)
# Entry(name='Юрий Иванов', birth_date=None, birth_place=None)
# Entry(name='Александр Зубков', birth_date=None, birth_place=None)
# Entry(name='Александр Зубков', birth_date=None, birth_place=None)
# Entry(name='Никита Крылов', birth_date=None, birth_place=None)
# Entry(name='Юрий Бирюков', birth_date=None, birth_place=None)
# Entry(name='Денис Лебедев', birth_date=None, birth_place=None)
# Entry(name='Денис Лебедев', birth_date=None, birth_place=None)
# Entry(name='Владимир Хрюнов', birth_date=None, birth_place=None)
# Entry(name='Игорь Бутман', birth_date=None, birth_place=None)
# Entry(name='Юрий Башмет', birth_date=None, birth_place=None)
# Entry(name='Мария Александрова', birth_date=None, birth_place=None)
# Entry(name='Юрий Башмет', birth_date=None, birth_place=None)
# Entry(name='Джон Ранкин', birth_date=None, birth_place=None)
# Entry(name='Мария Криттель', birth_date=None, birth_place=None)
# Entry(name='Брайан Уилсон', birth_date=None, birth_place=None)
# Entry(name='Майк Лав', birth_date=None, birth_place=None)
# Entry(name='Алан Джардин', birth_date=None, birth_place=None)
# Entry(name='Дэвид Маркс', birth_date=None, birth_place=None)
# Entry(name='Крис Браун', birth_date=None, birth_place=None)
# Entry(name='Тони Беннетт', birth_date=None, birth_place=None)
# Entry(name='из худшихЧерноморский', birth_date=None, birth_place=None)
# Entry(name='Майкл Блумберг', birth_date=None, birth_place=None)
# Entry(name='Эльвира Набиуллина', birth_date=None, birth_place=None)
# Entry(name='Ярослава Кузьминова', birth_date=None, birth_place=None)
# Entry(name='Эльвира Набиуллина', birth_date=None, birth_place=None)
# Entry(name='Арама Габрелянова', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Михаила Саакашвили', birth_date=None, birth_place=None)
# Entry(name='Кирилла Миронова', birth_date=None, birth_place=None)
# Entry(name='Вагит Алекперов', birth_date=None, birth_place=None)
# Entry(name='Игорь Шувалов', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Ларри Клейман', birth_date=None, birth_place=None)
# Entry(name='Марка Цукерберга', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Андрей Рябинский', birth_date=None, birth_place=None)
# Entry(name='Ричарда Макларена', birth_date=None, birth_place=None)
# Entry(name='Николай Грачев', birth_date=None, birth_place=None)
# Entry(name='Вагит Алекперов', birth_date=None, birth_place=None)
# Entry(name='Дмитрию Медведеву', birth_date=None, birth_place=None)
# Entry(name='Владимиру Путину', birth_date=None, birth_place=None)
# Entry(name='Андрея Костина', birth_date=None, birth_place=None)
# Entry(name='Сергей Прядкин', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Филипп Шмитт', birth_date=None, birth_place=None)
# Entry(name='Сандра Буллок', birth_date=None, birth_place=None)
# Entry(name='Олег Жолобов', birth_date=None, birth_place=None)
# Entry(name='Владимир Максимов', birth_date=None, birth_place=None)
# Entry(name='Андрея Колесникова', birth_date=None, birth_place=None)
# Entry(name='Никита Одинцов', birth_date=None, birth_place=None)
# Entry(name='Павла Астахова', birth_date=None, birth_place=None)
# Entry(name='Антон Астахов', birth_date=None, birth_place=None)
# Entry(name='Павла Астахова', birth_date=None, birth_place=None)
# Entry(name='Анна Левченко', birth_date=None, birth_place=None)
# Entry(name='Николай Никифоров', birth_date=None, birth_place=None)
# Entry(name='Ридли Скоттов', birth_date=None, birth_place=None)
# Entry(name='августа по', birth_date=None, birth_place=None)
# Entry(name='Кирилла Серебренникова', birth_date=None, birth_place=None)
# Entry(name='Александр Круглов', birth_date=None, birth_place=None)
# Entry(name='из баров', birth_date=None, birth_place=None)
# Entry(name='Стива Джобса', birth_date=None, birth_place=None)
# Entry(name='Станислав Воскресенский', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Дэвид Гибсон', birth_date=None, birth_place=None)
# Entry(name='Джейк Дэвис', birth_date=None, birth_place=None)
# Entry(name='Екатерина Михайлова', birth_date=None, birth_place=None)
# Entry(name='Константина Коровина', birth_date=None, birth_place=None)
# Entry(name='Петра Кончаловского', birth_date=None, birth_place=None)
# Entry(name='Александра Яковлева', birth_date=None, birth_place=None)
# Entry(name='Святослава Рериха', birth_date=None, birth_place=None)
# Entry(name='Ивана Айвазовского', birth_date=None, birth_place=None)
# Entry(name='Ильи Репина', birth_date=None, birth_place=None)
# Entry(name='Ивана Шишкина', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place='Севастополе')
# Entry(name='Андрея Курносенко', birth_date=None, birth_place=None)
# Entry(name='Андрей Курносенко', birth_date=None, birth_place=None)
# Entry(name='Дениса Сугробова', birth_date=None, birth_place=None)
# Entry(name='Мэрилин Монро', birth_date=None, birth_place=None)
# Entry(name='Мэрилин Монро', birth_date=None, birth_place=None)
# Entry(name='Ральфа Гринсона', birth_date=None, birth_place=None)
# Entry(name='Илья Сорокин', birth_date=None, birth_place=None)
# Entry(name='Игорь Шестеркин', birth_date=None, birth_place=None)
# Entry(name='Василий Демченко', birth_date=None, birth_place=None)
# Entry(name='Виктор Антипин', birth_date=None, birth_place=None)
# Entry(name='Алексей Береглазов', birth_date=None, birth_place=None)
# Entry(name='Илья Любушкин', birth_date=None, birth_place=None)
# Entry(name='Игорь Ожиганов', birth_date=None, birth_place=None)
# Entry(name='Андрей Миронов', birth_date=None, birth_place=None)
# Entry(name='Никита Гусев', birth_date=None, birth_place=None)
# Entry(name='Николай Прохоркин', birth_date=None, birth_place=None)
# Entry(name='Александр Барабанов', birth_date=None, birth_place=None)
# Entry(name='Анатолий Голышев', birth_date=None, birth_place=None)
# Entry(name='Валерий Ничушкин', birth_date=None, birth_place=None)
# Entry(name='Степан Санников', birth_date=None, birth_place=None)
# Entry(name='Сергей Шумаков', birth_date=None, birth_place=None)
# Entry(name='Константин Окулов', birth_date=None, birth_place=None)
# Entry(name='Владимир Ткачев', birth_date=None, birth_place=None)
# Entry(name='Вячеслав Лещенко', birth_date=None, birth_place=None)
# Entry(name='Павел Красковский', birth_date=None, birth_place=None)
# Entry(name='Леонид Левин', birth_date=None, birth_place=None)
# Entry(name='Наталья Пучкова', birth_date=None, birth_place=None)
# Entry(name='Владимира Чистюхина', birth_date=None, birth_place=None)
# Entry(name='Кристиной Киршнер', birth_date=None, birth_place=None)
# Entry(name='Владимир Пепеляев', birth_date=None, birth_place=None)
# Entry(name='Федором Бондарчуком', birth_date=None, birth_place=None)
# Entry(name='Александр Войтинский', birth_date=None, birth_place=None)
# Entry(name='Алексей Кравченко', birth_date=None, birth_place=None)
# Entry(name='Никита Волков', birth_date=None, birth_place=None)
# Entry(name='Ксения Алферова', birth_date=None, birth_place=None)
# Entry(name='Рамзан Кадыров', birth_date=None, birth_place=None)
# Entry(name='Федора Емельяненко', birth_date=None, birth_place=None)
# Entry(name='Федора Емельяненко', birth_date=None, birth_place=None)
# Entry(name='Рамзана Кадырова', birth_date=None, birth_place=None)
# Entry(name='Рамзана Кадырова', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Станислава Черчесова', birth_date=None, birth_place=None)
# Entry(name='Леонид Слуцкий', birth_date=None, birth_place=None)
# Entry(name='Давид Лагеркранц', birth_date=None, birth_place=None)
# Entry(name='Сергей Шойгу', birth_date=None, birth_place=None)
# Entry(name='Дженис Джонсен', birth_date=None, birth_place=None)
# Entry(name='Майк Джонсен', birth_date=None, birth_place=None)
# Entry(name='Дженис Джонсен', birth_date=None, birth_place=None)
# Entry(name='Джеймс Кэмерон', birth_date=None, birth_place=None)
# Entry(name='Джеймс Кэмерон', birth_date=None, birth_place=None)
# Entry(name='Джоша Фридмана', birth_date=None, birth_place=None)
# Entry(name='Стивена Спилберга', birth_date=None, birth_place=None)
# Entry(name='ли Фридман', birth_date=None, birth_place=None)
# Entry(name='Джеймса Кэмерона', birth_date=None, birth_place=None)
# Entry(name='Сандра Буллок', birth_date=None, birth_place=None)
# Entry(name='Сандра Буллок', birth_date=None, birth_place=None)
# Entry(name='Джим Парсонс', birth_date=None, birth_place=None)
# Entry(name='Шелдона Купера', birth_date=None, birth_place=None)
# Entry(name='Алла Забровская', birth_date=None, birth_place=None)
# Entry(name='Дмитрия Медведева', birth_date=None, birth_place=None)
# Entry(name='Александр Кокорин', birth_date=None, birth_place=None)
# Entry(name='Александер Бюттнер', birth_date=None, birth_place=None)
# Entry(name='Вагнер Лав', birth_date=None, birth_place=None)
# Entry(name='Вагнер Лав', birth_date=None, birth_place=None)
# Entry(name='Майкл Уилсон', birth_date=None, birth_place=None)
# Entry(name='Виктор Зюкин', birth_date=None, birth_place=None)
# Entry(name='Олега Сафонова', birth_date=None, birth_place=None)
# Entry(name='августа по', birth_date=None, birth_place=None)
# Entry(name='Стивен Лоуитс', birth_date=None, birth_place=None)
# Entry(name='Франческо Тотти', birth_date=None, birth_place=None)
# Entry(name='Дмитрием Медведевым', birth_date=None, birth_place=None)
# Entry(name='Сергей Когогин', birth_date=None, birth_place=None)
# Entry(name='Борис Гребенщиков', birth_date=None, birth_place=None)
# Entry(name='Геннадий Авраменко', birth_date=None, birth_place=None)
# Entry(name='Анатолием Гуницким', birth_date=None, birth_place=None)
# Entry(name='Михаилом Саакашвили', birth_date=None, birth_place=None)
# Entry(name='Вячеславом Бутусовым', birth_date=None, birth_place=None)
# Entry(name='Юрием Шевчуком', birth_date=None, birth_place=None)
# Entry(name='Максимом Леонидовым', birth_date=None, birth_place=None)
# Entry(name='Башевиса Зингера', birth_date=None, birth_place=None)
# Entry(name='Андре Янг', birth_date=None, birth_place=None)
# Entry(name='Гарри Бендинере', birth_date=None, birth_place=None)
# Entry(name='Андрей Костин', birth_date=None, birth_place=None)
# Entry(name='Игорю Шувалову', birth_date=None, birth_place=None)
# Entry(name='Йосипа Шимунича', birth_date=None, birth_place=None)
# Entry(name='Бонэм Картер', birth_date=None, birth_place=None)
# Entry(name='Алана Рикмана', birth_date=None, birth_place=None)
# Entry(name='Ислам Каримов', birth_date=None, birth_place=None)
# Entry(name='Стивена Кинга', birth_date=None, birth_place=None)
# Entry(name='Владимир Мединский', birth_date=None, birth_place=None)
# Entry(name='Алин Смит', birth_date=None, birth_place=None)
# Entry(name='Джастина Бибера', birth_date=None, birth_place=None)
# Entry(name='Дион Смита', birth_date=None, birth_place=None)
# Entry(name='Алин Смит', birth_date=None, birth_place=None)
# Entry(name='Сесара Родригеса', birth_date=None, birth_place=None)
# Entry(name='Дэвида Эберсмана', birth_date=None, birth_place=None)
# Entry(name='Джиму Керри', birth_date=None, birth_place=None)
# Entry(name='Джиму Керри', birth_date=None, birth_place=None)
# Entry(name='Джим Керри', birth_date=None, birth_place=None)
# Entry(name='Джима Керри', birth_date=None, birth_place=None)
# Entry(name='Арнольд Шварценеггер', birth_date=None, birth_place=None)
# Entry(name='Роман Широков', birth_date=None, birth_place=None)
# Entry(name='сами по', birth_date=None, birth_place=None)
# Entry(name='Грег Гекнер', birth_date=None, birth_place=None)
# Entry(name='Дэна Гликмана', birth_date=None, birth_place=None)
# Entry(name='Виктора Бондарева', birth_date=None, birth_place=None)
# Entry(name='оглы Махмудов', birth_date=None, birth_place=None)
# Entry(name='Евгений Кириллюк', birth_date=None, birth_place=None)
# Entry(name='Кузьме Минину', birth_date=None, birth_place=None)
# Entry(name='Дмитрию Пожарскому', birth_date=None, birth_place=None)
# Entry(name='Александра Фомина', birth_date=None, birth_place=None)
# Entry(name='арена московского', birth_date=None, birth_place=None)
# Entry(name='Сергея Шойгу', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Всеволода Боброва', birth_date=None, birth_place=None)
# Entry(name='аренами московского', birth_date=None, birth_place=None)
# Entry(name='Александра Радулова', birth_date=None, birth_place=None)
# Entry(name='Вячеслав Фетисов', birth_date=None, birth_place=None)
# Entry(name='Томаса Андерсона', birth_date=None, birth_place=None)
# Entry(name='Филип Сеймур', birth_date=None, birth_place=None)
# Entry(name='Шон Комбс', birth_date=None, birth_place=None)
# Entry(name='Кристал Ли', birth_date=None, birth_place=None)
# Entry(name='Михаил Погосян', birth_date=None, birth_place=None)
# Entry(name='сами по', birth_date=None, birth_place=None)
# Entry(name='Дарья Гаврилова', birth_date=None, birth_place=None)
# Entry(name='Светлана Кузнецова', birth_date=None, birth_place=None)
# Entry(name='Элины Свитолиной', birth_date=None, birth_place=None)
# Entry(name='Валентин Распутин', birth_date=None, birth_place=None)
# Entry(name='Валерий Ганичев', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Тулин', birth_date=None, birth_place=None)
# Entry(name='Алексей Моисеев', birth_date=None, birth_place=None)
# Entry(name='Иосиф Кобзон', birth_date=None, birth_place=None)
# Entry(name='Иосиф Кобзон', birth_date=None, birth_place=None)
# Entry(name='Виктора Цоя', birth_date=None, birth_place=None)
# Entry(name='Лев Шлосберг', birth_date=None, birth_place=None)
# Entry(name='Сергею Собянину', birth_date=None, birth_place=None)
# Entry(name='Александр Агеев', birth_date=None, birth_place=None)
# Entry(name='Виктора Цоя', birth_date=None, birth_place=None)
# Entry(name='Ирина Жирнова', birth_date=None, birth_place=None)
# Entry(name='Вадим Ампелонский', birth_date=None, birth_place=None)
# Entry(name='Станислава Казакова', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Зяблицев', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Андре Янг', birth_date=None, birth_place=None)
# Entry(name='Константином Новоселовым', birth_date=None, birth_place=None)
# Entry(name='Джейкоб Хансен', birth_date=None, birth_place=None)
# Entry(name='Александр Кокорин', birth_date=None, birth_place=None)
# Entry(name='Леонид Слуцкий', birth_date=None, birth_place=None)
# Entry(name='Сиенне Миллер', birth_date=None, birth_place=None)
# Entry(name='Роберту Паттинсону', birth_date=None, birth_place=None)
# Entry(name='Джеймс Грэй', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Горин', birth_date=None, birth_place=None)
# Entry(name='Александр Овечкин', birth_date=None, birth_place=None)
# Entry(name='Александр Овечкин', birth_date=None, birth_place=None)
# Entry(name='Александр Овечкин', birth_date=None, birth_place=None)
# Entry(name='Алан Дзагоев', birth_date=None, birth_place=None)
# Entry(name='Вагнер Лав', birth_date=None, birth_place=None)
# Entry(name='Джона Леннона', birth_date=None, birth_place=None)
# Entry(name='Элвиса Пресли', birth_date=None, birth_place=None)
# Entry(name='Джону Леннону', birth_date=None, birth_place=None)
# Entry(name='Курту Кобейну', birth_date=None, birth_place=None)
# Entry(name='Майклу Джексону', birth_date=None, birth_place=None)
# Entry(name='Анатолий Калмыков', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Роберт Гиббс', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Дениса Глушакова', birth_date=None, birth_place=None)
# Entry(name='Дениса Глушакова', birth_date=None, birth_place=None)
# Entry(name='Сергей Лавров', birth_date=None, birth_place=None)
# Entry(name='Софико Шеварнадзе', birth_date=None, birth_place=None)
# Entry(name='Сергей Лавров', birth_date=None, birth_place=None)
# Entry(name='Сантьяго Бернабеу', birth_date=None, birth_place=None)
# Entry(name='из охотников', birth_date=None, birth_place=None)
# Entry(name='Джордж Буш', birth_date=None, birth_place=None)
# Entry(name='Сергей Шойгу', birth_date=None, birth_place=None)
# Entry(name='Виталий Чуркин', birth_date=None, birth_place=None)
# Entry(name='Владимир Фортов', birth_date=None, birth_place=None)
# ...
# Entry(name='Кристин Сиделко', birth_date=None, birth_place=None)
# Entry(name='Коринн Рэй', birth_date=None, birth_place=None)
# Entry(name='Екатерина Кронгауз', birth_date=None, birth_place=None)
# Entry(name='Екатерина Кронгауз', birth_date=None, birth_place=None)
# Entry(name='Александру Винокурову', birth_date=None, birth_place=None)
# Entry(name='Ирина Калитеевская', birth_date=None, birth_place=None)
# Entry(name='Александром Винокуровым', birth_date=None, birth_place=None)
# Entry(name='Александр Винокуров', birth_date=None, birth_place=None)
# Entry(name='Максимом Кашулинским', birth_date=None, birth_place=None)
# Entry(name='Екатерина Кронгауз', birth_date=None, birth_place=None)
# Entry(name='Ксения Собчак', birth_date=None, birth_place=None)
# Entry(name='Андрей Димитров', birth_date=None, birth_place=None)
# Entry(name='Евгения Володина', birth_date=None, birth_place=None)
# Entry(name='Андрей Малахов', birth_date=None, birth_place=None)
# Entry(name='Вячеславом Манучаровым', birth_date=None, birth_place=None)
# Entry(name='Ксении Собчак', birth_date=None, birth_place=None)
# Entry(name='Чулпан Хаматовой', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Ксения Собчак', birth_date=None, birth_place=None)
# Entry(name='Ксенией Собчак', birth_date=None, birth_place=None)
# Entry(name='Ксения Собчак', birth_date=None, birth_place=None)
# Entry(name='Олег Сиенко', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Еремеев', birth_date=None, birth_place=None)
# Entry(name='Дмитрием Медведевым', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Иван Озеров', birth_date=None, birth_place=None)
# Entry(name='Андрей Мельников', birth_date=None, birth_place=None)
# Entry(name='Юрий Исаев', birth_date=None, birth_place=None)
# Entry(name='из городов', birth_date=None, birth_place=None)
# Entry(name='Алексею Кузнецову', birth_date=None, birth_place=None)
# Entry(name='Алексея Кузнецова', birth_date=None, birth_place=None)
# Entry(name='Эльвира Набиуллина', birth_date=None, birth_place=None)
# Entry(name='Сильвио Берлускони', birth_date=None, birth_place=None)
# Entry(name='Дмитрием Медведевым', birth_date=None, birth_place=None)
# Entry(name='Вадим Шипачев', birth_date=None, birth_place=None)
# Entry(name='Евгений Дадонов', birth_date=None, birth_place=None)
# Entry(name='Артемий Панарин', birth_date=None, birth_place=None)
# Entry(name='Олегом Знарком', birth_date=None, birth_place=None)
# Entry(name='Антон Азизбекян', birth_date=None, birth_place=None)
# Entry(name='Юрий Кузьмин', birth_date=None, birth_place=None)
# Entry(name='Виктора Януковича', birth_date=None, birth_place=None)
# Entry(name='Элизабет Тейлор', birth_date=None, birth_place=None)
# Entry(name='Элизабет Тейлор', birth_date=None, birth_place=None)
# Entry(name='Элизабет Тейлор', birth_date=None, birth_place=None)
# Entry(name='Майкл Джексон', birth_date=None, birth_place=None)
# Entry(name='Алексея Ремизова', birth_date='1877 году', birth_place='Москве')
# Entry(name='Алексей Ремизов', birth_date=None, birth_place=None)
# Entry(name='Натальи Резниковой', birth_date=None, birth_place=None)
# Entry(name='Алексей Ремизов', birth_date=None, birth_place=None)
# Entry(name='Марк Шагал', birth_date=None, birth_place=None)
# Entry(name='Василий Кандинский', birth_date=None, birth_place=None)
# Entry(name='Пабло Пикассо', birth_date=None, birth_place=None)
# Entry(name='Василий Березуцкий', birth_date=None, birth_place=None)
# Entry(name='Алан Дзагоев', birth_date=None, birth_place=None)
# Entry(name='Евгений Гинер', birth_date=None, birth_place=None)
# Entry(name='Майкл Адамс', birth_date=None, birth_place=None)
# Entry(name='Николаю Толстых', birth_date=None, birth_place=None)
# Entry(name='Василия Березуцкого', birth_date=None, birth_place=None)
# Entry(name='Эдуардом Шеварнадзе', birth_date=None, birth_place=None)
# Entry(name='Алексей Венедиктов', birth_date=None, birth_place=None)
# Entry(name='Владимир Варфоломеев', birth_date=None, birth_place=None)
# Entry(name='Алексей Венедиктов', birth_date=None, birth_place=None)
# Entry(name='Юрия Федутинова', birth_date=None, birth_place=None)
# Entry(name='Алексей Венедиктов', birth_date=None, birth_place=None)
# Entry(name='Алексей Венедиктов', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Франсуа Олланд', birth_date=None, birth_place=None)
# Entry(name='Француа Олланд', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Сергей Горьков', birth_date=None, birth_place=None)
# Entry(name='Владимира Дмитриева', birth_date=None, birth_place=None)
# Entry(name='Олега Дормана', birth_date=None, birth_place=None)
# Entry(name='Лилианне Лунгиной', birth_date=None, birth_place=None)
# Entry(name='Алексей Пивоваров', birth_date=None, birth_place=None)
# Entry(name='Георгия Жукова', birth_date=None, birth_place=None)
# Entry(name='Леонида Парфенова', birth_date=None, birth_place=None)
# Entry(name='Чарльз Дарвин', birth_date=None, birth_place=None)
# Entry(name='Руслан Бальбек', birth_date=None, birth_place=None)
# Entry(name='Сергей Карякин', birth_date=None, birth_place=None)
# Entry(name='Сергей Карякин', birth_date=None, birth_place=None)
# Entry(name='Сергей Карякин', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Алан Джойс', birth_date=None, birth_place=None)
# Entry(name='Алексей Улюкаев', birth_date=None, birth_place=None)
# Entry(name='Гарегин Тосунян', birth_date=None, birth_place=None)
# Entry(name='Сергея Давыдова', birth_date=None, birth_place=None)
# Entry(name='Курбан Бердыев', birth_date=None, birth_place=None)
# Entry(name='Кима Чельстрема', birth_date=None, birth_place=None)
# Entry(name='Майклом Амодтом', birth_date=None, birth_place=None)
# Entry(name='Михаила Фрадкова', birth_date=None, birth_place=None)
# Entry(name='Павла Фрадкова', birth_date=None, birth_place=None)
# Entry(name='Ольга Дергунова', birth_date=None, birth_place=None)
# Entry(name='Михаила Фрадкова', birth_date=None, birth_place=None)
# Entry(name='Ольга Дергунова', birth_date=None, birth_place=None)
# Entry(name='О Павле', birth_date=None, birth_place=None)
# Entry(name='Николая Патрушева', birth_date=None, birth_place=None)
# Entry(name='Павел Фрадков', birth_date=None, birth_place=None)
# Entry(name='Юрий Петров', birth_date=None, birth_place=None)
# Entry(name='Мухарбек Декажев', birth_date=None, birth_place=None)
# Entry(name='Михаил Мишустин', birth_date=None, birth_place=None)
# Entry(name='Дмитрию Киселеву', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Светлана Миронюк', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Киселев', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Михаилу Мамиашвили', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Свищев', birth_date=None, birth_place=None)
# Entry(name='Алексей Попов', birth_date=None, birth_place=None)
# Entry(name='Владимиром Путиным', birth_date=None, birth_place=None)
# Entry(name='Юрий Белкин', birth_date=None, birth_place=None)
# Entry(name='Наталью Кашкарову', birth_date=None, birth_place=None)
# Entry(name='Денис Евсюков', birth_date=None, birth_place=None)
# Entry(name='ли возможноВ', birth_date=None, birth_place=None)
# Entry(name='Виктором Рагозиным', birth_date=None, birth_place=None)
# Entry(name='Дмитрием Менделеевым', birth_date=None, birth_place=None)
# Entry(name='Мария Шарапова', birth_date=None, birth_place=None)
# Entry(name='Анатолий Васильченко', birth_date=None, birth_place=None)
# Entry(name='Юлия Ефимова', birth_date=None, birth_place=None)
# Entry(name='Евгений Рылов', birth_date=None, birth_place=None)
# Entry(name='Елена Алексеева', birth_date=None, birth_place=None)
# Entry(name='Александр Бортников', birth_date=None, birth_place=None)
# Entry(name='Александр Медведев', birth_date=None, birth_place=None)
# Entry(name='Евгения Малкина', birth_date=None, birth_place=None)
# Entry(name='Ольга Подчуфарова', birth_date=None, birth_place=None)
# Entry(name='Екатерине Юрловой', birth_date=None, birth_place=None)
# Entry(name='Александру Валову', birth_date=None, birth_place=None)
# Entry(name='Александр Попков', birth_date=None, birth_place=None)
# Entry(name='Дмитрию Салтыковскому', birth_date=None, birth_place=None)
# Entry(name='Бернарда Голдберга', birth_date=None, birth_place=None)
# Entry(name='Максимом Григорьевым', birth_date=None, birth_place=None)
# Entry(name='Вячеслава Жигалова', birth_date=None, birth_place=None)
# Entry(name='Петру Порошенко', birth_date=None, birth_place=None)
# Entry(name='Эриха Ледерера', birth_date=None, birth_place=None)
# Entry(name='Эриха Ледерера', birth_date=None, birth_place=None)
# Entry(name='Эриха Ледерера', birth_date=None, birth_place=None)
# Entry(name='Анзор Музаев', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Билл Мюррей', birth_date=None, birth_place=None)
# Entry(name='Биллом Мюрреем', birth_date=None, birth_place=None)
# Entry(name='Майклом Джорданом', birth_date=None, birth_place=None)
# Entry(name='герой Мюррея', birth_date=None, birth_place=None)
# Entry(name='Памелой Андерсон', birth_date=None, birth_place=None)
# Entry(name='Франсуа Олланда', birth_date=None, birth_place=None)
# Entry(name='Андрея Костина', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Сергей Глазьев', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Юрию Осипову', birth_date=None, birth_place=None)
# Entry(name='Сергей Глазьев', birth_date=None, birth_place=None)
# Entry(name='Сергей Глазьев', birth_date=None, birth_place=None)
# Entry(name='Александр Покрышкин', birth_date=None, birth_place=None)
# Entry(name='Николай Гулаев', birth_date=None, birth_place=None)
# Entry(name='из толстой', birth_date=None, birth_place=None)
# Entry(name='Фрэнком Баумом', birth_date=None, birth_place=None)
# Entry(name='Фрэнка Баума', birth_date=None, birth_place=None)
# Entry(name='Джеймса Франко', birth_date=None, birth_place=None)
# Entry(name='Джон Дуглас', birth_date=None, birth_place=None)
# Entry(name='Алексей Моисеев', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='Гарри Поттера', birth_date=None, birth_place=None)
# Entry(name='Гарри Поттера', birth_date=None, birth_place=None)
# Entry(name='Джинни Поттер', birth_date=None, birth_place=None)
# Entry(name='Алексей Воробьев', birth_date=None, birth_place=None)
# Entry(name='Алексей Воробьев', birth_date=None, birth_place=None)
# Entry(name='Демьяна Кудрявцева', birth_date=None, birth_place=None)
# Entry(name='Алексей Воробьев', birth_date=None, birth_place=None)
# Entry(name='Алишером Усмановым', birth_date=None, birth_place=None)
# Entry(name='Екатерина Краснова', birth_date=None, birth_place=None)
# Entry(name='Григория Пирумова', birth_date=None, birth_place=None)
# Entry(name='Олег Иванов', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Сергеев', birth_date=None, birth_place=None)
# Entry(name='Александр Коченов', birth_date=None, birth_place=None)
# Entry(name='Никита Колесников', birth_date=None, birth_place=None)
# Entry(name='Михаил Дудко', birth_date=None, birth_place=None)
# Entry(name='Всеволод Чаплин', birth_date=None, birth_place=None)
# Entry(name='Йозефом Блаттером', birth_date=None, birth_place=None)
# Entry(name='Юрий Шевчук', birth_date=None, birth_place=None)
# Entry(name='Юрия Шевчука', birth_date=None, birth_place=None)
# Entry(name='Владимиром Путиным', birth_date=None, birth_place=None)
# Entry(name='Полины Гагариной', birth_date=None, birth_place=None)
# Entry(name='Юлия Савичева', birth_date=None, birth_place=None)
# Entry(name='Полина Гагарина', birth_date=None, birth_place=None)
# Entry(name='Борис Гребенщиков', birth_date=None, birth_place=None)
# Entry(name='Ежи Энгель', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Слай Купер', birth_date=None, birth_place=None)
# Entry(name='Натан Дрейк', birth_date=None, birth_place=None)
# Entry(name='Юрий Зубарев', birth_date=None, birth_place=None)
# Entry(name='Алексей Улюкаев', birth_date=None, birth_place=None)
# Entry(name='Владимира Путина', birth_date=None, birth_place=None)
# Entry(name='Игоря Смольникова', birth_date=None, birth_place=None)
# Entry(name='Эмма Уотсон', birth_date=None, birth_place=None)
# Entry(name='Эмма Уотсон', birth_date=None, birth_place=None)
# Entry(name='Гарри Поттер', birth_date=None, birth_place=None)
# Entry(name='Эммы Уотсон', birth_date=None, birth_place=None)
# Entry(name='Майк Ли', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Рогозин', birth_date=None, birth_place=None)
# Entry(name='Евгений Кузнецов', birth_date=None, birth_place=None)
# Entry(name='Артемий Панарин', birth_date=None, birth_place=None)
# Entry(name='Сергей Шойгу', birth_date=None, birth_place=None)
# Entry(name='С Ефимовой', birth_date=None, birth_place=None)
# Entry(name='Юлии Ефимовой', birth_date=None, birth_place=None)
# Entry(name='Артема Пацева', birth_date=None, birth_place=None)
# Entry(name='Алексея Емелина', birth_date=None, birth_place=None)
# Entry(name='Артуру Джанибекяну', birth_date=None, birth_place=None)
# Entry(name='Гарику Мартиросяну', birth_date=None, birth_place=None)
# Entry(name='Александр Овечкин', birth_date=None, birth_place=None)
# Entry(name='Александр Семин', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Орлов', birth_date=None, birth_place=None)
# Entry(name='Чинг По', birth_date=None, birth_place=None)
# Entry(name='Урсула Грабовская', birth_date=None, birth_place=None)
# Entry(name='Феликса Фалька', birth_date=None, birth_place=None)
# Entry(name='Пола Бертона', birth_date=None, birth_place=None)
# Entry(name='Барак Обама', birth_date=None, birth_place=None)
# Entry(name='Эльвира Набиуллина', birth_date=None, birth_place=None)
# Entry(name='Александр Бастрыкин', birth_date=None, birth_place=None)
# Entry(name='Сержем Саргсяном', birth_date=None, birth_place=None)
# Entry(name='Валерий Пермяков', birth_date=None, birth_place=None)
# Entry(name='Сергей Куприянов', birth_date=None, birth_place=None)
# Entry(name='Игорь Сечин', birth_date=None, birth_place=None)
# Entry(name='Алексей Миллер', birth_date=None, birth_place=None)
# Entry(name='Гузель Санжапова', birth_date=None, birth_place=None)
# Entry(name='У Санжаповой', birth_date=None, birth_place=None)
# Entry(name='Эд Чавес', birth_date=None, birth_place=None)
# Entry(name='Дин Армстронг', birth_date=None, birth_place=None)
# Entry(name='Фредди Крюгера', birth_date=None, birth_place=None)
# Entry(name='Сэм Дэвидсон', birth_date=None, birth_place=None)
# Entry(name='Фредди Крюгер', birth_date=None, birth_place=None)
# Entry(name='Александр Старовойтов', birth_date=None, birth_place=None)
# Entry(name='Владимир Путин', birth_date=None, birth_place=None)
# Entry(name='из страховой', birth_date=None, birth_place=None)
# Entry(name='Евгений Гонтмахер', birth_date=None, birth_place=None)
# Entry(name='Дмитрий Медведев', birth_date=None, birth_place=None)
# Entry(name='из Кингстонского', birth_date=None, birth_place=None)
# Entry(name='Людмила Вороненко', birth_date=None, birth_place=None)
# Entry(name='Андреем Виноградовым', birth_date=None, birth_place=None)
# Entry(name='Людмила Вороненко', birth_date=None, birth_place=None)
# Entry(name='Леонид Слуцкий', birth_date=None, birth_place=None)
# Entry(name='Аркадия Ротенберга', birth_date=None, birth_place=None)
# Entry(name='Константина Малофеева', birth_date=None, birth_place=None)
# Entry(name='Константина Малофеева', birth_date=None, birth_place=None)
# Entry(name='Джорджа Буша', birth_date=None, birth_place=None)
# Entry(name='Билла Клинтона', birth_date=None, birth_place=None)
# Entry(name='Сергея Полонского', birth_date=None, birth_place=None)
